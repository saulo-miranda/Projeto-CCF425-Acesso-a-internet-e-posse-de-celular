# %%
# !pip install xlrd==1.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xlrd==1.2.0 in /usr/local/lib/python3.7/dist-packages (1.2.0)

# %%
# !pip install odfpy
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: odfpy in /usr/local/lib/python3.7/dist-packages (1.4.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from odfpy) (0.7.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !wget https://raw.githubusercontent.com/saulo-miranda/Projeto-CCF425-Acesso-a-internet-e-posse-de-celular/main/ods/01usointernet.ods
# !wget https://raw.githubusercontent.com/saulo-miranda/Projeto-CCF425-Acesso-a-internet-e-posse-de-celular/main/ods/01_Utilizacao_da_Internet.ods
# !wget https://raw.githubusercontent.com/saulo-miranda/Projeto-CCF425-Acesso-a-internet-e-posse-de-celular/main/ods/01_Utilizacao_da_Internet.ods.1
# Out:
# --2022-07-26 02:52:17--  https://raw.githubusercontent.com/saulo-miranda/Projeto-CCF425-Acesso-a-internet-e-posse-de-celular/main/ods/01usointernet.ods
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 272885 (266K) [application/octet-stream]
# Saving to: ‘01usointernet.ods.1’
#
# 01usointernet.ods.1 100%[===================>] 266.49K  --.-KB/s    in 0.03s
#
# 2022-07-26 02:52:18 (8.06 MB/s) - ‘01usointernet.ods.1’ saved [272885/272885]
#
# --2022-07-26 02:52:18--  https://raw.githubusercontent.com/saulo-miranda/Projeto-CCF425-Acesso-a-internet-e-posse-de-celular/main/ods/01_Utilizacao_da_Internet.ods
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 267386 (261K) [application/octet-stream]
# Saving to: ‘01_Utilizacao_da_Internet.ods.2’
#
# 01_Utilizacao_da_In 100%[===================>] 261.12K  --.-KB/s    in 0.03s
#
# 2022-07-26 02:52:18 (8.32 MB/s) - ‘01_Utilizacao_da_Internet.ods.2’ saved [267386/267386]
#
# --2022-07-26 02:52:18--  https://raw.githubusercontent.com/saulo-miranda/Projeto-CCF425-Acesso-a-internet-e-posse-de-celular/main/ods/01_Utilizacao_da_Internet.ods.1
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 261266 (255K) [application/octet-stream]
# Saving to: ‘01_Utilizacao_da_Internet.ods.1.1’
#
# 01_Utilizacao_da_In 100%[===================>] 255.14K  --.-KB/s    in 0.03s
#
# 2022-07-26 02:52:18 (7.72 MB/s) - ‘01_Utilizacao_da_Internet.ods.1.1’ saved [261266/261266]

# %%
arquivos = ["01usointernet.ods","01_Utilizacao_da_Internet.ods", "01_Utilizacao_da_Internet.ods.1"]

# %% [markdown]
# # Dataframe da Idade por Região

# %% [markdown]
# ### Leitura separada pelo ano

# %%
dfs_idade_regiao = []
def ler(arquivos, dfs):
    for arq in arquivos:
        dfIdade = pd.read_excel(arq, sheet_name="Tab 1.1.2.1 a 1.1.2.3", usecols="A:G", header=4)
        dfs.append(dfIdade)

ler(arquivos, dfs_idade_regiao)

# %% [markdown]
# ### Tratamento dos dados

# %% [markdown]
# Ao exibir pode-se notar, tabelas não nomeadas, assim como uma nota de fonte, e valores nulos, além de também os valores somados respectivos a cada sexo, que não é interessante manter para o estudo do dataframe, portanto deve-se tratar tudo isso.

# %%
dfs_idade_regiao[1]
# Out:
#                                            Unnamed: 0  Unnamed: 1     Norte  \
# 0                                               Total   95356.075  6412.201
# 1                                        10 a 14 anos   11057.668   803.903
# 2                                        15 a 17 anos    8631.644   708.367
# 3                                       18 ou 19 anos    5635.180   466.258
# 4                                        20 a 24 anos   12352.738   977.348
# 5                                        25 a 29 anos   11434.858   856.495
# 6                                        30 a 34 anos   11185.759   755.217
# 7                                        35 a 39 anos    9046.871   602.057
# 8                                        40 a 44 anos    7636.492   453.127
# 9                                        45 a 49 anos    6020.643   308.796
# 10                                       50 a 54 anos    4923.395   225.729
# 11                                       55 a 59 anos    3272.110   129.029
# 12                                    60 anos ou mais    4158.717   125.875
# 13                                             Homens   45580.367  3067.032
# 14                                       10 a 14 anos    5517.924   403.613
# 15                                       15 a 17 anos    4296.798   365.595
# 16                                      18 ou 19 anos    2806.148   231.541
# 17                                       20 a 24 anos    6047.179   467.874
# 18                                       25 a 29 anos    5452.564   402.566
# 19                                       30 a 34 anos    5153.796   344.843
# 20                                       35 a 39 anos    4135.938   265.403
# 21                                       40 a 44 anos    3536.655   209.099
# 22                                       45 a 49 anos    2764.788   144.847
# 23                                       50 a 54 anos    2284.789   100.130
# 24                                       55 a 59 anos    1507.183    61.495
# 25                                    60 anos ou mais    2076.605    70.026
# 26                                           Mulheres   49775.708  3345.169
# 27                                       10 a 14 anos    5539.744   400.290
# 28                                       15 a 17 anos    4334.846   342.772
# 29                                      18 ou 19 anos    2829.032   234.717
# 30                                       20 a 24 anos    6305.559   509.474
# 31                                       25 a 29 anos    5982.294   453.929
# 32                                       30 a 34 anos    6031.963   410.374
# 33                                       35 a 39 anos    4910.933   336.654
# 34                                       40 a 44 anos    4099.837   244.028
# 35                                       45 a 49 anos    3255.855   163.949
# 36                                       50 a 54 anos    2638.606   125.599
# 37                                       55 a 59 anos    1764.927    67.534
# 38                                    60 anos ou mais    2082.112    55.849
# 39                                                NaN         NaN       NaN
# 40  Fonte: IBGE, Diretoria de Pesquisas, Coordenaç...         NaN       NaN
#
#      Nordeste    Sudeste        Sul  Centro-Oeste
# 0   20144.488  46107.871  14841.161      7850.354
# 1    2752.179   4832.138   1672.465       996.983
# 2    2324.066   3705.800   1234.981       658.430
# 3    1510.757   2416.214    797.706       444.245
# 4    2968.260   5537.328   1822.943      1046.859
# 5    2573.709   5354.287   1676.467       973.900
# 6    2260.366   5482.167   1755.987       932.022
# 7    1685.258   4489.466   1452.412       817.678
# 8    1325.511   3971.191   1235.946       650.717
# 9     982.742   3203.070   1045.365       480.670
# 10    758.569   2735.415    844.294       359.388
# 11    473.456   1877.077    571.860       220.688
# 12    529.615   2503.718    730.735       268.774
# 13   9304.548  22156.695   7238.014      3814.078
# 14   1338.519   2419.722    843.676       512.394
# 15   1129.589   1830.845    627.826       342.943
# 16    729.398   1212.184    398.252       234.773
# 17   1406.639   2737.408    913.246       522.012
# 18   1144.754   2576.093    832.917       496.234
# 19    993.392   2549.086    845.754       420.721
# 20    723.831   2092.969    687.881       365.854
# 21    579.174   1850.842    599.105       298.435
# 22    425.110   1498.908    475.200       220.723
# 23    351.733   1276.702    391.585       164.639
# 24    217.705    864.784    265.518        97.681
# 25    264.704   1247.152    357.054       137.669
# 26  10839.940  23951.176   7603.147      4036.276
# 27   1413.660   2412.416    828.789       484.589
# 28   1194.477   1874.955    607.155       315.487
# 29    781.359   1204.030    399.454       209.472
# 30   1561.621   2799.920    909.697       524.847
# 31   1428.955   2778.194    843.550       477.666
# 32   1266.974   2933.081    910.233       511.301
# 33    961.427   2396.497    764.531       451.824
# 34    746.337   2120.349    636.841       352.282
# 35    557.632   1704.162    570.165       259.947
# 36    406.836   1458.713    452.709       194.749
# 37    255.751   1012.293    306.342       123.007
# 38    264.911   1256.566    373.681       131.105
# 39        NaN        NaN        NaN           NaN
# 40        NaN        NaN        NaN           NaN

# %%
def tratar(dfs):
    for i in range(len(dfs)):
        dfs[i] = dfs[i].drop(dfs[i].index[[0, 13, 26, 39, 40]])
        dfs[i].rename(columns={'Unnamed: 0': 'Grupo de Idades', 'Unnamed: 1': 'Brasil'}, inplace=True)
tratar(dfs_idade_regiao)
dfs_idade_regiao[0]
# Out:
#     Grupo de Idades     Brasil    Norte  Nordeste   Sudeste       Sul  \
# 1      10 a 14 anos  10783.226  725.355  2587.526  4889.733  1677.194
# 2      15 a 17 anos   8060.214  634.300  2049.379  3523.644  1184.240
# 3     18 ou 19 anos   5076.276  424.409  1247.823  2229.160   766.013
# 4      20 a 24 anos  11160.476  838.329  2604.753  5077.307  1698.644
# 5      25 a 29 anos  10213.670  705.847  2161.808  4913.158  1539.424
# 6      30 a 34 anos  10044.708  614.403  1973.991  5035.279  1556.768
# 7      35 a 39 anos   8154.923  477.491  1482.327  4255.841  1251.900
# 8      40 a 44 anos   6496.596  357.974  1161.722  3329.750  1117.711
# 9      45 a 49 anos   5396.742  235.479   867.607  2962.412   924.767
# 10     50 a 54 anos   4107.347  179.664   597.442  2267.551   757.653
# 11     55 a 59 anos   2759.365  100.541   392.060  1581.917   481.821
# 12  60 anos ou mais   3318.516   83.137   452.493  2045.673   539.020
# 14     10 a 14 anos   5450.971  346.548  1266.508  2512.607   861.059
# 15     15 a 17 anos   3978.028  312.729   996.525  1739.218   606.588
# 16    18 ou 19 anos   2546.228  205.545   623.606  1125.156   392.816
# 17     20 a 24 anos   5394.983  390.660  1199.528  2485.150   837.153
# 18     25 a 29 anos   4829.269  332.089   982.134  2355.455   727.343
# 19     30 a 34 anos   4661.000  282.809   900.520  2344.261   739.133
# 20     35 a 39 anos   3771.858  219.059   661.104  1997.090   590.443
# 21     40 a 44 anos   3010.112  154.861   505.636  1562.051   537.593
# 22     45 a 49 anos   2560.228  111.981   398.158  1417.335   437.476
# 23     50 a 54 anos   1945.203   87.611   291.279  1076.666   339.883
# 24     55 a 59 anos   1320.984   53.429   179.580   754.001   235.873
# 25  60 anos ou mais   1703.903   49.704   232.543  1032.936   281.844
# 27     10 a 14 anos   5332.255  378.807  1321.018  2377.126   816.135
# 28     15 a 17 anos   4082.186  321.571  1052.854  1784.426   577.652
# 29    18 ou 19 anos   2530.048  218.864   624.217  1104.004   373.197
# 30     20 a 24 anos   5765.493  447.669  1405.225  2592.157   861.491
# 31     25 a 29 anos   5384.401  373.758  1179.674  2557.703   812.081
# 32     30 a 34 anos   5383.708  331.594  1073.471  2691.018   817.635
# 33     35 a 39 anos   4383.065  258.432   821.223  2258.751   661.457
# 34     40 a 44 anos   3486.484  203.113   656.086  1767.699   580.118
# 35     45 a 49 anos   2836.514  123.498   469.449  1545.077   487.291
# 36     50 a 54 anos   2162.144   92.053   306.163  1190.885   417.770
# 37     55 a 59 anos   1438.381   47.112   212.480   827.916   245.948
# 38  60 anos ou mais   1614.613   33.433   219.950  1012.737   257.176
#
#     Centro-Oeste
# 1        903.418
# 2        668.651
# 3        408.871
# 4        941.443
# 5        893.433
# 6        864.267
# 7        687.364
# 8        529.439
# 9        406.477
# 10       305.037
# 11       203.026
# 12       198.193
# 14       464.249
# 15       322.968
# 16       199.105
# 17       482.492
# 18       432.248
# 19       394.277
# 20       304.162
# 21       249.971
# 22       195.278
# 23       149.764
# 24        98.101
# 25       106.876
# 27       439.169
# 28       345.683
# 29       209.766
# 30       458.951
# 31       461.185
# 32       469.990
# 33       383.202
# 34       279.468
# 35       211.199
# 36       155.273
# 37       104.925
# 38        91.317

# %% [markdown]
# ### Separação dos dados

# %% [markdown]
# Podemos notar que os dados, de Homens e Mulheres assim como seus totais estão juntos, portanto é interessante separar cada um deles criando uma coluna por sexo.

# %%
def separar(dfs):
    newdfs = []
    for df in dfs:
        s = pd.Series([])
        dfIdadeHomen = df.iloc[12:24]  # Homens
        dfIdadeMulher = df.iloc[24:]  # Mulheres
        dfIdadeHomen.insert(7, "Sexo", "Masculino")
        dfIdadeMulher.insert(7, "Sexo", "Feminino")
        dfIdadeTotal = pd.concat([dfIdadeMulher, dfIdadeHomen], sort=False)
        newdfs.append(dfIdadeTotal)
    return newdfs
  
dfs_idade_regiao = separar(dfs_idade_regiao)
dfs_idade_regiao[0] #Dataframe das idades de homens por região de 2013 que utilizam a internet
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   after removing the cwd from sys.path.
#     Grupo de Idades    Brasil    Norte  Nordeste   Sudeste      Sul  \
# 27     10 a 14 anos  5332.255  378.807  1321.018  2377.126  816.135
# 28     15 a 17 anos  4082.186  321.571  1052.854  1784.426  577.652
# 29    18 ou 19 anos  2530.048  218.864   624.217  1104.004  373.197
# 30     20 a 24 anos  5765.493  447.669  1405.225  2592.157  861.491
# 31     25 a 29 anos  5384.401  373.758  1179.674  2557.703  812.081
# 32     30 a 34 anos  5383.708  331.594  1073.471  2691.018  817.635
# 33     35 a 39 anos  4383.065  258.432   821.223  2258.751  661.457
# 34     40 a 44 anos  3486.484  203.113   656.086  1767.699  580.118
# 35     45 a 49 anos  2836.514  123.498   469.449  1545.077  487.291
# 36     50 a 54 anos  2162.144   92.053   306.163  1190.885  417.770
# 37     55 a 59 anos  1438.381   47.112   212.480   827.916  245.948
# 38  60 anos ou mais  1614.613   33.433   219.950  1012.737  257.176
# 14     10 a 14 anos  5450.971  346.548  1266.508  2512.607  861.059
# 15     15 a 17 anos  3978.028  312.729   996.525  1739.218  606.588
# 16    18 ou 19 anos  2546.228  205.545   623.606  1125.156  392.816
# 17     20 a 24 anos  5394.983  390.660  1199.528  2485.150  837.153
# 18     25 a 29 anos  4829.269  332.089   982.134  2355.455  727.343
# 19     30 a 34 anos  4661.000  282.809   900.520  2344.261  739.133
# 20     35 a 39 anos  3771.858  219.059   661.104  1997.090  590.443
# 21     40 a 44 anos  3010.112  154.861   505.636  1562.051  537.593
# 22     45 a 49 anos  2560.228  111.981   398.158  1417.335  437.476
# 23     50 a 54 anos  1945.203   87.611   291.279  1076.666  339.883
# 24     55 a 59 anos  1320.984   53.429   179.580   754.001  235.873
# 25  60 anos ou mais  1703.903   49.704   232.543  1032.936  281.844
#
#     Centro-Oeste       Sexo
# 27       439.169   Feminino
# 28       345.683   Feminino
# 29       209.766   Feminino
# 30       458.951   Feminino
# 31       461.185   Feminino
# 32       469.990   Feminino
# 33       383.202   Feminino
# 34       279.468   Feminino
# 35       211.199   Feminino
# 36       155.273   Feminino
# 37       104.925   Feminino
# 38        91.317   Feminino
# 14       464.249  Masculino
# 15       322.968  Masculino
# 16       199.105  Masculino
# 17       482.492  Masculino
# 18       432.248  Masculino
# 19       394.277  Masculino
# 20       304.162  Masculino
# 21       249.971  Masculino
# 22       195.278  Masculino
# 23       149.764  Masculino
# 24        98.101  Masculino
# 25       106.876  Masculino

# %% [markdown]
# ### Tipos e nomes dos dados

# %% [markdown]
# Ambos os dados são do tipo float, exceto a coluna grupo de idade e sexo que é object, além disso não possuem valores nulos, isso vale para todos os dataframes separados também.

# %%
dfs_idade_regiao[0].dtypes
# Out:
# Grupo de Idades     object
# Brasil             float64
# Norte              float64
# Nordeste           float64
# Sudeste            float64
# Sul                float64
# Centro-Oeste       float64
# Sexo                object
# dtype: object

# %%
dfs_idade_regiao[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 27 to 25
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Grupo de Idades  24 non-null     object
#  1   Brasil           24 non-null     float64
#  2   Norte            24 non-null     float64
#  3   Nordeste         24 non-null     float64
#  4   Sudeste          24 non-null     float64
#  5   Sul              24 non-null     float64
#  6   Centro-Oeste     24 non-null     float64
#  7   Sexo             24 non-null     object
# dtypes: float64(6), object(2)
# memory usage: 1.7+ KB

# %% [markdown]
# ### Média, Mediana e desvio padrão
# Abaixo estão valores referentes aos grupos de idades conforme a utilização de internet em diferentes regiões do Brasil.

# %%
print("\nAno de 2013")
print(dfs_idade_regiao[0].describe())
print("\nAno de 2014")
print(dfs_idade_regiao[1].describe())
print("\nAno de 2015")
print(dfs_idade_regiao[2].describe())
# Out:
# Ano de 2013
#             Brasil       Norte     Nordeste      Sudeste         Sul  \
# count    24.000000   24.000000    24.000000    24.000000   24.000000
# mean   3565.502458  224.038708   732.455458  1754.642708  562.298125
# std    1486.454551  127.834497   396.801651   641.493959  213.972077
# min    1320.984000   33.433000   179.580000   754.001000  235.873000
# 25%    2438.072000  106.999000   375.159250  1119.868000  387.911250
# 50%    3629.171000  218.961500   658.595000  1753.458500  578.885000
# 75%    4955.015500  331.717750  1058.008250  2360.872750  757.370000
# max    5765.493000  447.669000  1405.225000  2691.018000  861.491000
#
#        Centro-Oeste
# count     24.000000
# mean     292.067458
# std      137.918059
# min       91.317000
# 25%      185.276750
# 50%      291.815000
# 75%      433.978250
# max      482.492000
#
# Ano de 2014
#             Brasil       Norte     Nordeste      Sudeste         Sul  \
# count    24.000000   24.000000    24.000000    24.000000   24.000000
# mean   3973.169792  267.175042   839.353667  1921.161292  618.381708
# std    1549.131454  144.581615   440.524116   643.695323  216.263304
# min    1507.183000   55.849000   217.705000   864.784000  265.518000
# 25%    2733.242500  140.035000   420.541500  1271.668000  399.153500
# 50%    4117.887500  254.715500   763.848000  1862.898500  617.490500
# 75%    5468.904000  400.859000  1212.601250  2452.063000  835.575250
# max    6305.559000  509.474000  1561.621000  2933.081000  913.246000
#
#        Centro-Oeste
# count     24.000000
# mean     327.098083
# std      147.410094
# min       97.681000
# 25%      205.791250
# 50%      329.215000
# 75%      479.396750
# max      524.847000
#
# Ano de 2015
#             Brasil       Norte     Nordeste      Sudeste         Sul  \
# count    24.000000   24.000000    24.000000    24.000000   24.000000
# mean   4253.462083  279.804625   909.628500  2051.957625  656.623833
# std    1473.508996  138.736803   440.599023   603.867259  201.327553
# min    1804.767000   74.906000   243.138000  1020.185000  328.899000
# 25%    2839.666250  162.058000   496.956000  1585.714000  458.335000
# 50%    4360.254500  297.911000   898.906500  1998.036000  653.153000
# 75%    5515.669750  382.543250  1274.492000  2617.350250  837.417500
# max    6290.013000  495.573000  1595.321000  3010.256000  950.365000
#
#        Centro-Oeste
# count     24.000000
# mean     355.447500
# std      139.895161
# min      131.490000
# 25%      230.987250
# 50%      345.645500
# 75%      476.287500
# max      540.425000

# %% [markdown]
# ### Grupo de idade que mais utilizam a internet no Brasil
#
# ---

# %%
print("\nAno de 2013")
i = dfs_idade_regiao[0][dfs_idade_regiao[0]['Brasil']==dfs_idade_regiao[0]['Brasil'].max()].index[0]
print(dfs_idade_regiao[0]['Grupo de Idades'][i])
print("\nAno de 2014")
i = dfs_idade_regiao[1][dfs_idade_regiao[1]['Brasil']==dfs_idade_regiao[1]['Brasil'].max()].index[0]
print(dfs_idade_regiao[1]['Grupo de Idades'][i])
print("\nAno de 2015")
i = dfs_idade_regiao[2][dfs_idade_regiao[2]['Brasil']==dfs_idade_regiao[2]['Brasil'].max()].index[0]
print(dfs_idade_regiao[2]['Grupo de Idades'][i])
# Out:
# Ano de 2013
# 20 a 24 anos
#
# Ano de 2014
# 20 a 24 anos
#
# Ano de 2015
# 20 a 24 anos

# %% [markdown]
# ### Total de usúarios masculinos e femininos usuários da internet

# %%
print("\nAno de 2013")
print("Total de Homens:")
print(dfs_idade_regiao[0]['Brasil'][dfs_idade_regiao[0]['Sexo'] == 'Masculino'].sum())
print("Total de Mulheres:")
print(dfs_idade_regiao[0]['Brasil'][dfs_idade_regiao[0]['Sexo'] == 'Feminino'].sum())
print("\nAno de 2014")
print("Total de Homens:")
print(dfs_idade_regiao[1]['Brasil'][dfs_idade_regiao[1]['Sexo'] == 'Masculino'].sum())
print("Total de Mulheres:")
print(dfs_idade_regiao[1]['Brasil'][dfs_idade_regiao[1]['Sexo'] == 'Feminino'].sum())
print("\nAno de 2015")
print("Total de Homens:")
print(dfs_idade_regiao[2]['Brasil'][dfs_idade_regiao[2]['Sexo'] == 'Masculino'].sum())
print("Total de Mulheres:")
print(dfs_idade_regiao[2]['Brasil'][dfs_idade_regiao[2]['Sexo'] == 'Feminino'].sum())
# Out:
# Ano de 2013
# Total de Homens:
# 41172.767
# Total de Mulheres:
# 44399.292
#
# Ano de 2014
# Total de Homens:
# 45580.367
# Total de Mulheres:
# 49775.708000000006
#
# Ano de 2015
# Total de Homens:
# 48591.545999999995
# Total de Mulheres:
# 53491.543999999994

# %% [markdown]
# ### Gráficos a respeitos das idades e região

# %% [markdown]
# ### Grupo de Idades x Usuários de internet do Brasil em 2013

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dfs_idade_regiao[0], x='Sudeste', y='Grupo de Idades',palette="pastel", orient='h')
g.set_xlabel('Usuários de internet no Brasil')
plt.show()

# %% [markdown]
# ### Grupo de Idades x Usuários de internet do Brasil em 2013 dividido por sexo

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dfs_idade_regiao[0], x='Sudeste', y='Grupo de Idades',palette="Set2",hue = "Sexo", orient='h')
g.set_xlabel('Usuários de internet no Brasil')
plt.show()

# %% [markdown]
# ### Comparação entre Usuários no Brasil ao longo dos anos

# %%
newdf1 = dfs_idade_regiao[0].copy()
newdf2 = dfs_idade_regiao[1].copy()
newdf3 = dfs_idade_regiao[2].copy()
newdf1.insert(8,"Ano",2013)
newdf2.insert(8,"Ano",2014)
newdf3.insert(8,"Ano",2015)
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Brasil', y='Grupo de Idades',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Usuários de internet no Brasil')
g.set(title='Número de usuário de Internet por Faixa Etaria e Ano')
plt.show()

# %% [markdown]
# ### Usúarios que utilizam a internet ao longo dos anos

# %%
newdf1 = dfs_idade_regiao[0].copy()
newdf2 = dfs_idade_regiao[1].copy()
newdf3 = dfs_idade_regiao[2].copy()
newdf1.insert(8,"Ano",2013)
newdf2.insert(8,"Ano",2014)
newdf3.insert(8,"Ano",2015)
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
plt.figure(figsize=(10,10))
groupIdades = newdf.groupby('Ano').sum().reset_index()
g=sns.barplot(data=groupIdades, x='Ano', y='Brasil',palette="Paired", orient='v')
g.set_ylabel('Usuários de internet no Brasil')
g.set(title='Número de usuário de Internet por Ano')
plt.show()

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72 entries, 27 to 25
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Grupo de Idades  72 non-null     object
#  1   Brasil           72 non-null     float64
#  2   Norte            72 non-null     float64
#  3   Nordeste         72 non-null     float64
#  4   Sudeste          72 non-null     float64
#  5   Sul              72 non-null     float64
#  6   Centro-Oeste     72 non-null     float64
#  7   Sexo             72 non-null     object
#  8   Ano              72 non-null     int64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 5.6+ KB

# %% [markdown]
# ## Regressão Linear

# %% [markdown]
# #### Verificando a matriz de coeficiente de pearson

# %%
temp = newdf.copy()
temp['Grupo de Idades'] = newdf['Grupo de Idades'].astype('category')
#temp['Grupo de Idades'] = temp['Grupo de Idades'].cat.codes
temp['Sexo'] = newdf['Sexo'].astype('category')
#temp['Sexo'] = temp['Sexo'].cat.codes
temp = pd.get_dummies(temp)
correlation = temp.corr()
matrix = np.triu(temp.corr())
plt.figure(figsize=(20,20))
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True, center=0, cmap='coolwarm', mask=matrix)

# %% [markdown]
# #### Utilizando Regressão para prever os dados em anos futuros

# %%
from traitlets.traitlets import default
from sklearn.linear_model import LinearRegression


#Remodelando os dados para regressão

temp = newdf.copy()
temp['Grupo de Idades'] = newdf['Grupo de Idades'].astype('category')
#temp['Grupo de Idades'] = temp['Grupo de Idades'].cat.codes
temp['Sexo'] = newdf['Sexo'].astype('category')
#temp['Sexo'] = temp['Sexo'].cat.codes
temp = pd.get_dummies(temp)


def retornaGrupos(x):
  lista = {
      0: "Grupo de Idades_10 a 14 anos",
      1: "Grupo de Idades_15 a 17 anos",
      2: "Grupo de Idades_18 ou 19 anos",
      3: "Grupo de Idades_20 a 24 anos",
      4: "Grupo de Idades_25 a 29 anos",
      5: "Grupo de Idades_30 a 34 anos",
      6: "Grupo de Idades_35 a 39 anos",
      7: "Grupo de Idades_40 a 44 anos",
      8: "Grupo de Idades_45 a 49 anos",
      9: "Grupo de Idades_50 a 54 anos",
      10: "Grupo de Idades_55 a 59 anos",
      11: "Grupo de Idades_60 anos ou mais",
  }
  return lista.get(x,default)


def retornaSexo(x):
  lista = {
      0: 'Sexo_Feminino',
      1: 'Sexo_Masculino'
  }
  return lista.get(x,default)


#Renomeando as colunas do df

def renomearGrupos(x):
  lista = {
      0: "10 a 14 anos",
      1: "15 a 17 anos",
      2: "18 ou 19 anos",
      3: "20 a 24 anos",
      4: "25 a 29 anos",
      5: "30 a 34 anos",
      6: "35 a 39 anos",
      7: "40 a 44 anos",
      8: "45 a 49 anos",
      9: "50 a 54 anos",
      10: "55 a 59 anos",
      11: "60 anos ou mais"
  }
  return lista.get(x,default)

def renomearSexo(x):
  lista = {
      0: "Feminino",
      1: "Masculino",
    }
  return lista.get(x,default)

#Calcular dado a partir de seus coeficientes.

def calcula(ano,coef1,grupo,coef2,sexo,coef3,interc):
  return interc + ano * coef1 + grupo *coef2 + sexo * coef3

#Aplicando regressão linear 

def aplicarRegressao(df,ldf,col,ano,grupo,sexo):
  X = df[['Ano',retornaGrupos(grupo),retornaSexo(sexo)]]
  Y = df[col]
  lm = LinearRegression()
  lm.fit(X, Y)
  #print("grupo ",grupo," sexo",sexo, "coef ", lm.coef_)
  return calcula(ano,lm.coef_[0],1,lm.coef_[1],1,lm.coef_[2],lm.intercept_)

#Utilização de regressão para criação de um novo dataframe.

def regressao(df,ano,cols):
  ldf = []
  data = []
  for i in range(2):
    for j in range(12):
      ldf.append(j)  
      for col in cols :
        ldf.append(aplicarRegressao(df,ldf,col,ano,j,i))
      ldf.append(i)
      ldf.append(ano)
      data.append(ldf)
      ldf = []
  rdf = pd.DataFrame(data, columns=['Grupo de Idades','Brasil','Norte','Nordeste','Sudeste','Sul','Centro-Oeste','Sexo','Ano'])    
  rdf['Grupo de Idades'] = rdf['Grupo de Idades'].apply(lambda x: renomearGrupos(x))
  rdf['Sexo'] = rdf['Sexo'].apply(lambda x: renomearSexo(x))  
  return rdf

#Obtendo Dataframe a partir da regressão para o ano de 2016 e 2017.

cols = ['Brasil','Norte','Nordeste','Sudeste','Sul','Centro-Oeste']
df2016 = regressao(temp,2016,cols)
df2017 = regressao(temp,2017,cols)

# %% [markdown]
# #### Exibindo os novos dataframes previstos a partir da regressão para os anos de 2016 e 2017

# %%
df2016
# Out:
#     Grupo de Idades       Brasil       Norte     Nordeste      Sudeste  \
# 0      10 a 14 anos  6325.896125  451.935986  1589.794750  2797.576875
# 1      15 a 17 anos  5094.491125  412.107986  1357.992750  2190.849708
# 2     18 ou 19 anos  3590.116125  291.016486   945.592083  1562.045875
# 3      20 a 24 anos  6874.235292  533.585986  1677.672250  3071.647542
# 4      25 a 29 anos  6409.333458  472.838153  1475.823250  2975.970375
# 5      30 a 34 anos  6355.063458  427.157653  1363.710083  3062.038208
# 6      35 a 39 anos  5452.833292  362.790319  1107.816417  2674.581042
# 7      40 a 44 anos  4655.787125  286.276819   911.906917  2332.364875
# 8      45 a 49 anos  3913.932292  220.044153   736.208583  1999.430875
# 9      50 a 54 anos  3322.634958  179.449653   604.472417  1737.323042
# 10     55 a 59 anos  2525.157125  133.955819   472.207750  1319.696208
# 11  60 anos ou mais  2958.216458  128.284319   509.934250  1641.784375
# 12     10 a 14 anos  5983.622125  427.572847  1472.910667  2649.829625
# 13     15 a 17 anos  4752.217125  387.744847  1241.108667  2043.102458
# 14    18 ou 19 anos  3247.842125  266.653347   828.708000  1414.298625
# 15     20 a 24 anos  6531.961292  509.222847  1560.788167  2923.900292
# 16     25 a 29 anos  6067.059458  448.475014  1358.939167  2828.223125
# 17     30 a 34 anos  6012.789458  402.794514  1246.826000  2914.290958
# 18     35 a 39 anos  5110.559292  338.427181   990.932333  2526.833792
# 19     40 a 44 anos  4313.513125  261.913681   795.022833  2184.617625
# 20     45 a 49 anos  3571.658292  195.681014   619.324500  1851.683625
# 21     50 a 54 anos  2980.360958  155.086514   487.588333  1589.575792
# 22     55 a 59 anos  2182.883125  109.592681   355.323667  1171.948958
# 23  60 anos ou mais  2615.942458  103.921181   393.050167  1494.037125
#
#             Sul  Centro-Oeste       Sexo   Ano
# 0    934.435986    552.152528   Feminino  2016
# 1    722.714653    410.826028   Feminino  2016
# 2    500.509486    290.952194   Feminino  2016
# 3   1008.849319    582.480194   Feminino  2016
# 4    931.325486    553.376194   Feminino  2016
# 5    961.099486    541.058028   Feminino  2016
# 6    826.607653    481.037861   Feminino  2016
# 7    730.852153    394.386361   Feminino  2016
# 8    635.881653    322.367028   Feminino  2016
# 9    543.606819    257.783028   Feminino  2016
# 10   405.218819    194.078528   Feminino  2016
# 11   467.090986    211.122528   Feminino  2016
# 12   903.257764    530.051222  Masculino  2016
# 13   691.536431    388.724722  Masculino  2016
# 14   469.331264    268.850889  Masculino  2016
# 15   977.671097    560.378889  Masculino  2016
# 16   900.147264    531.274889  Masculino  2016
# 17   929.921264    518.956722  Masculino  2016
# 18   795.429431    458.936556  Masculino  2016
# 19   699.673931    372.285056  Masculino  2016
# 20   604.703431    300.265722  Masculino  2016
# 21   512.428597    235.681722  Masculino  2016
# 22   374.040597    171.977222  Masculino  2016
# 23   435.912764    189.021222  Masculino  2016

# %%
df2017
# Out:
#     Grupo de Idades       Brasil       Norte     Nordeste      Sudeste  \
# 0      10 a 14 anos  6669.875938  479.818944  1678.381271  2946.234333
# 1      15 a 17 anos  5438.470938  439.990944  1446.579271  2339.507167
# 2     18 ou 19 anos  3934.095938  318.899444  1034.178604  1710.703333
# 3      20 a 24 anos  7218.215104  561.468944  1766.258771  3220.305000
# 4      25 a 29 anos  6753.313271  500.721111  1564.409771  3124.627833
# 5      30 a 34 anos  6699.043271  455.040611  1452.296604  3210.695667
# 6      35 a 39 anos  5796.813104  390.673278  1196.402937  2823.238500
# 7      40 a 44 anos  4999.766938  314.159778  1000.493437  2481.022333
# 8      45 a 49 anos  4257.912104  247.927111   824.795104  2148.088333
# 9      50 a 54 anos  3666.614771  207.332611   693.058937  1885.980500
# 10     55 a 59 anos  2869.136937  161.838778   560.794271  1468.353667
# 11  60 anos ou mais  3302.196271  156.167278   598.520771  1790.441833
# 12     10 a 14 anos  6327.601938  455.455806  1561.497187  2798.487083
# 13     15 a 17 anos  5096.196938  415.627806  1329.695187  2191.759917
# 14    18 ou 19 anos  3591.821938  294.536306   917.294521  1562.956083
# 15     20 a 24 anos  6875.941104  537.105806  1649.374687  3072.557750
# 16     25 a 29 anos  6411.039271  476.357972  1447.525687  2976.880583
# 17     30 a 34 anos  6356.769271  430.677472  1335.412521  3062.948417
# 18     35 a 39 anos  5454.539104  366.310139  1079.518854  2675.491250
# 19     40 a 44 anos  4657.492938  289.796639   883.609354  2333.275083
# 20     45 a 49 anos  3915.638104  223.563972   707.911021  2000.341083
# 21     50 a 54 anos  3324.340771  182.969472   576.174854  1738.233250
# 22     55 a 59 anos  2526.862937  137.475639   443.910187  1320.606417
# 23  60 anos ou mais  2959.922271  131.804139   481.636687  1642.694583
#
#             Sul  Centro-Oeste       Sexo   Ano
# 0    981.598840    583.842549   Feminino  2017
# 1    769.877507    442.516049   Feminino  2017
# 2    547.672340    322.642215   Feminino  2017
# 3   1056.012174    614.170215   Feminino  2017
# 4    978.488340    585.066215   Feminino  2017
# 5   1008.262340    572.748049   Feminino  2017
# 6    873.770507    512.727882   Feminino  2017
# 7    778.015007    426.076382   Feminino  2017
# 8    683.044507    354.057049   Feminino  2017
# 9    590.769674    289.473049   Feminino  2017
# 10   452.381674    225.768549   Feminino  2017
# 11   514.253840    242.812549   Feminino  2017
# 12   950.420618    561.741243  Masculino  2017
# 13   738.699285    420.414743  Masculino  2017
# 14   516.494118    300.540910  Masculino  2017
# 15  1024.833951    592.068910  Masculino  2017
# 16   947.310118    562.964910  Masculino  2017
# 17   977.084118    550.646743  Masculino  2017
# 18   842.592285    490.626576  Masculino  2017
# 19   746.836785    403.975076  Masculino  2017
# 20   651.866285    331.955743  Masculino  2017
# 21   559.591451    267.371743  Masculino  2017
# 22   421.203451    203.667243  Masculino  2017
# 23   483.075618    220.711243  Masculino  2017

# %% [markdown]
# #### Exibindo Gráficos para comparação com os demais dados do Dataframe

# %%
dftodosanos = pd.concat([newdf,df2016,df2017], sort=False)
plt.figure(figsize=(10,10))
groupIdades = dftodosanos.groupby('Ano').sum().reset_index()
g=sns.barplot(data=groupIdades, x='Ano', y='Brasil',palette="Paired", orient='v')
g.set_ylabel('Usuários de internet no Brasil')
g.set(title='Número de usuário de Internet por Ano')
plt.show()

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dftodosanos, x='Brasil', y='Grupo de Idades',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Usuários de internet no Brasil')
g.set(title='Número de usuário de Internet por Faixa Etária e Ano')
plt.show()

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dftodosanos[dftodosanos['Ano'] == 2016], x='Sudeste', y='Grupo de Idades',palette="Set2",hue = "Sexo", orient='h')
g.set_xlabel('Usuários de internet no Brasil')
g.set(title='Número de usuário de Internet por Faixa Etária e Sexo no Ano de 2016')
plt.show()

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dftodosanos[dftodosanos['Ano'] == 2017], x='Sudeste', y='Grupo de Idades',palette="Set2",hue = "Sexo", orient='h')
g.set_xlabel('Usuários de internet no Brasil')
g.set(title='Número de usuário de Internet por Faixa Etária e Sexo no Ano de 2017')
plt.show()

# %% [markdown]
# # Data Frame do sexo por anos de estudo

# %% [markdown]
# ### Leitura separada pelo ano

# %%
dfs_sexo_anosdeestudo = []
def ler(arquivos, dfs):
    for arq in arquivos:
        dfIdade = pd.read_excel(arq, sheet_name="Tab 1.1.6.1 a 1.1.6.3", usecols="A:G", header=4)
        dfs.append(dfIdade)

ler(arquivos, dfs_sexo_anosdeestudo)

# %% [markdown]
# ### Tratamento dos dados

# %% [markdown]
# Ao exibir pode-se notar, tabelas não nomeadas, assim como uma nota de fonte, e valores nulos, além de também os valores somados respectivos a cada sexo, que não é interessante manter para o estudo do dataframe, portanto deve-se tratar tudo isso.

# %%
dfs_sexo_anosdeestudo[1]
# Out:
#                                            Unnamed: 0  Unnamed: 1     Norte  \
# 0                                               Total   95356.075  6412.201
# 1                      Sem instrução e menos de 1 ano     804.274    69.417
# 2                                          1 a 3 anos    3582.713   248.662
# 3                                          4 a 7 anos   17509.151  1271.403
# 4                                         8 a 10 anos   18573.472  1350.138
# 5                                        11 a 14 anos   39474.813  2664.728
# 6                                     15 anos ou mais   15322.903   799.933
# 7                                    Não determinados      88.749     7.920
# 8                                              Homens   45580.367  3067.032
# 9                      Sem instrução e menos de 1 ano     425.117    38.932
# 10                                         1 a 3 anos    1916.513   144.106
# 11                                         4 a 7 anos    9123.094   680.076
# 12                                        8 a 10 anos    9364.407   671.402
# 13                                       11 a 14 anos   18279.035  1205.436
# 14                                    15 anos ou mais    6433.094   322.879
# 15                                   Não determinados      39.107     4.201
# 16                                           Mulheres   49775.708  3345.169
# 17                     Sem instrução e menos de 1 ano     379.157    30.485
# 18                                         1 a 3 anos    1666.200   104.556
# 19                                         4 a 7 anos    8386.057   591.327
# 20                                        8 a 10 anos    9209.065   678.736
# 21                                       11 a 14 anos   21195.778  1459.292
# 22                                    15 anos ou mais    8889.809   477.054
# 23                                   Não determinados      49.642     3.719
# 24                                                NaN         NaN       NaN
# 25  Fonte: IBGE, Diretoria de Pesquisas, Coordenaç...         NaN       NaN
#
#      Nordeste    Sudeste        Sul  Centro-Oeste
# 0   20144.488  46107.871  14841.161      7850.354
# 1     155.954    342.791    150.770        85.342
# 2     885.659   1563.736    559.664       324.992
# 3    4316.541   7744.663   2639.841      1536.703
# 4    4042.619   8604.135   3063.486      1513.094
# 5    8294.048  19586.503   5912.071      3017.463
# 6    2413.228   8245.358   2495.944      1368.440
# 7      36.439     20.685     19.385         4.320
# 8    9304.548  22156.695   7238.014      3814.078
# 9      89.786    169.931     77.746        48.722
# 10    463.315    826.960    307.053       175.079
# 11   2250.702   3977.072   1380.777       834.467
# 12   1944.352   4347.163   1622.002       779.488
# 13   3636.216   9217.593   2812.193      1407.597
# 14    904.359   3610.034   1028.557       567.265
# 15     15.818      7.942      9.686         1.460
# 16  10839.940  23951.176   7603.147      4036.276
# 17     66.168    172.860     73.024        36.620
# 18    422.344    736.776    252.611       149.913
# 19   2065.839   3767.591   1259.064       702.236
# 20   2098.267   4256.972   1441.484       733.606
# 21   4657.832  10368.910   3099.878      1609.866
# 22   1508.869   4635.324   1467.387       801.175
# 23     20.621     12.743      9.699         2.860
# 24        NaN        NaN        NaN           NaN
# 25        NaN        NaN        NaN           NaN

# %% [markdown]
# ### Separação dos dados

# %%
def tratar(dfs):
    for i in range(len(dfs)):
        dfs[i] = dfs[i].drop(dfs[i].index[[0,8,16,24,25]])
        dfs[i].rename(columns={'Unnamed: 0': 'Grupo de anos de estudos', 'Unnamed: 1': 'Brasil'}, inplace=True)
tratar(dfs_sexo_anosdeestudo)
dfs_sexo_anosdeestudo[0]
# Out:
#           Grupo de anos de estudos     Brasil     Norte  Nordeste    Sudeste  \
# 1   Sem instrução e menos de 1 ano    878.236    63.870   158.839    420.928
# 2                       1 a 3 anos   3321.599   228.257   811.759   1504.395
# 3                       4 a 7 anos  15194.399  1018.481  3530.057   7038.639
# 4                      8 a 10 anos  16332.027  1084.948  3431.126   7757.595
# 5                     11 a 14 anos  35699.743  2242.444  7277.608  17921.883
# 6                  15 anos ou mais  14052.985   725.088  2342.914   7446.355
# 7                 Não determinados     93.070    13.841    26.628     21.630
# 9   Sem instrução e menos de 1 ano    478.526    30.313    92.487    231.983
# 10                      1 a 3 anos   1829.070   121.337   453.651    819.952
# 11                      4 a 7 anos   7981.729   528.729  1851.855   3683.856
# 12                     8 a 10 anos   8184.233   537.460  1659.123   3895.477
# 13                    11 a 14 anos  16675.253  1031.952  3259.120   8464.802
# 14                 15 anos ou mais   5978.883   291.277   908.356   3294.183
# 15                Não determinados     45.073     5.957    12.529     11.673
# 17  Sem instrução e menos de 1 ano    399.710    33.557    66.352    188.945
# 18                      1 a 3 anos   1492.529   106.920   358.108    684.443
# 19                      4 a 7 anos   7212.670   489.752  1678.202   3354.783
# 20                     8 a 10 anos   8147.794   547.488  1772.003   3862.118
# 21                    11 a 14 anos  19024.490  1210.492  4018.488   9457.081
# 22                 15 anos ou mais   8074.102   433.811  1434.558   4152.172
# 23                Não determinados     47.997     7.884    14.099      9.957
#
#          Sul  Centro-Oeste
# 1    163.012        71.587
# 2    489.904       287.284
# 3   2346.934      1260.288
# 4   2741.074      1317.284
# 5   5467.098      2790.710
# 6   2261.254      1277.374
# 7     25.879         5.092
# 9     83.990        39.753
# 10   272.329       161.801
# 11  1238.875       678.414
# 12  1430.153       662.020
# 13  2618.337      1301.042
# 14   931.357       553.710
# 15    12.163         2.751
# 17    79.022        31.834
# 18   217.575       125.483
# 19  1108.059       581.874
# 20  1310.921       655.264
# 21  2848.761      1489.668
# 22  1329.897       723.664
# 23    13.716         2.341

# %% [markdown]
# Podemos notar que os dados, de Homens e Mulheres assim como seus totais estão juntos, portanto é interessante separar cada um deles criando uma coluna por ano de estudo.

# %%
def separar(dfs):
    newdfs = []
    for df in dfs:
        s = pd.Series([])
        dfIdadeHomen = df.iloc[7:14]  # Homens
        dfIdadeMulher = df.iloc[14:]  # Mulheres
        dfIdadeHomen.insert(7, "Sexo", "Masculino")
        dfIdadeMulher.insert(7, "Sexo", "Feminino")
        dfIdadeTotal = pd.concat([dfIdadeHomen, dfIdadeMulher], sort=False)
        newdfs.append(dfIdadeTotal)
    return newdfs
  
dfs_sexo_anosdeestudo = separar(dfs_sexo_anosdeestudo)
dfs_sexo_anosdeestudo[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   after removing the cwd from sys.path.
#           Grupo de anos de estudos     Brasil     Norte  Nordeste   Sudeste  \
# 9   Sem instrução e menos de 1 ano    478.526    30.313    92.487   231.983
# 10                      1 a 3 anos   1829.070   121.337   453.651   819.952
# 11                      4 a 7 anos   7981.729   528.729  1851.855  3683.856
# 12                     8 a 10 anos   8184.233   537.460  1659.123  3895.477
# 13                    11 a 14 anos  16675.253  1031.952  3259.120  8464.802
# 14                 15 anos ou mais   5978.883   291.277   908.356  3294.183
# 15                Não determinados     45.073     5.957    12.529    11.673
# 17  Sem instrução e menos de 1 ano    399.710    33.557    66.352   188.945
# 18                      1 a 3 anos   1492.529   106.920   358.108   684.443
# 19                      4 a 7 anos   7212.670   489.752  1678.202  3354.783
# 20                     8 a 10 anos   8147.794   547.488  1772.003  3862.118
# 21                    11 a 14 anos  19024.490  1210.492  4018.488  9457.081
# 22                 15 anos ou mais   8074.102   433.811  1434.558  4152.172
# 23                Não determinados     47.997     7.884    14.099     9.957
#
#          Sul  Centro-Oeste       Sexo
# 9     83.990        39.753  Masculino
# 10   272.329       161.801  Masculino
# 11  1238.875       678.414  Masculino
# 12  1430.153       662.020  Masculino
# 13  2618.337      1301.042  Masculino
# 14   931.357       553.710  Masculino
# 15    12.163         2.751  Masculino
# 17    79.022        31.834   Feminino
# 18   217.575       125.483   Feminino
# 19  1108.059       581.874   Feminino
# 20  1310.921       655.264   Feminino
# 21  2848.761      1489.668   Feminino
# 22  1329.897       723.664   Feminino
# 23    13.716         2.341   Feminino

# %% [markdown]
# ### Tipos e nomes dos dados

# %% [markdown]
# Ambos os dados são do tipo float, exceto a coluna grupo de idade e sexo que é object, além disso não possuem valores nulos, isso vale para todos os dataframes separados também.

# %%
dfs_sexo_anosdeestudo[1].dtypes
# Out:
# Grupo de anos de estudos     object
# Brasil                      float64
# Norte                       float64
# Nordeste                    float64
# Sudeste                     float64
# Sul                         float64
# Centro-Oeste                float64
# Sexo                         object
# dtype: object

# %%
dfs_sexo_anosdeestudo[1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14 entries, 9 to 23
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Grupo de anos de estudos  14 non-null     object
#  1   Brasil                    14 non-null     float64
#  2   Norte                     14 non-null     float64
#  3   Nordeste                  14 non-null     float64
#  4   Sudeste                   14 non-null     float64
#  5   Sul                       14 non-null     float64
#  6   Centro-Oeste              14 non-null     float64
#  7   Sexo                      14 non-null     object
# dtypes: float64(6), object(2)
# memory usage: 1008.0+ bytes

# %% [markdown]
# ### Média, Mediana e desvio padrão
# Abaixo estão valores referentes aos grupos de idades conforme a utilização de internet em diferentes regiões do Brasil.

# %%
print("\nAno de 2013")
print(dfs_sexo_anosdeestudo[0].describe())
print("\nAno de 2014")
print(dfs_sexo_anosdeestudo[1].describe())
print("\nAno de 2015")
print(dfs_sexo_anosdeestudo[2].describe())
# Out:
# Ano de 2013
#              Brasil        Norte     Nordeste      Sudeste          Sul  \
# count     14.000000    14.000000    14.000000    14.000000    14.000000
# mean    6112.289929   384.066357  1255.637929  3007.958929   963.939643
# std     6031.693643   379.723324  1242.397470  3021.189104   930.684578
# min       45.073000     5.957000    12.529000     9.957000    12.163000
# 25%      732.026750    51.897750   158.892250   345.098000   117.386250
# 50%     6595.776500   362.544000  1171.457000  3324.483000  1019.708000
# 75%     8129.371000   535.277250  1748.552750  3887.137250  1325.153000
# max    19024.490000  1210.492000  4018.488000  9457.081000  2848.761000
#
#        Centro-Oeste
# count     14.000000
# mean     500.687071
# std      475.837430
# min        2.341000
# 25%       61.185500
# 50%      567.792000
# 75%      674.315500
# max     1489.668000
#
# Ano de 2014
#              Brasil        Norte     Nordeste       Sudeste          Sul  \
# count     14.000000    14.000000    14.000000     14.000000    14.000000
# mean    6811.148214   458.014357  1438.892000   3293.419357  1060.082929
# std     6720.500688   458.708014  1439.791752   3321.972296  1013.985979
# min       39.107000     3.719000    15.818000      7.942000     9.686000
# 25%      735.387750    55.338000   172.925500    313.839000   121.462250
# 50%     7409.575500   399.966500  1206.614000   3688.812500  1143.810500
# 75%     9187.572250   676.902500  2090.160000   4324.615250  1460.911250
# max    21195.778000  1459.292000  4657.832000  10368.910000  3099.878000
#
#        Centro-Oeste
# count     14.000000
# mean     560.739571
# std      520.854792
# min        1.460000
# 25%       74.019750
# 50%      634.750500
# 75%      795.753250
# max     1609.866000
#
# Ano de 2015
#              Brasil        Norte     Nordeste       Sudeste          Sul  \
# count     14.000000    14.000000    14.000000     14.000000    14.000000
# mean    7291.649286   479.665071  1559.363143   3517.641643  1125.640857
# std     7120.367861   470.985741  1548.448383   3512.129214  1057.859878
# min       59.148000     5.774000    16.273000     13.805000    15.809000
# 25%      882.227250    59.921250   201.850000    403.563750   140.553000
# 50%     7970.898000   423.931500  1319.044500   3929.673500  1272.618000
# 75%     9838.991000   709.386000  2208.624250   4712.412500  1600.829000
# max    22520.968000  1472.784000  5058.380000  11043.040000  3160.151000
#
#        Centro-Oeste
# count     14.000000
# mean     609.338571
# std      566.442644
# min        3.646000
# 25%       84.442250
# 50%      701.117500
# 75%      858.369500
# max     1786.613000

# %% [markdown]
# Total de usúarios masculinos, femininos que são usuários da internet

# %%
print("\nAno de 2013")
print("Total de Homens:")
print(dfs_sexo_anosdeestudo[0]['Brasil'][dfs_sexo_anosdeestudo[0]['Sexo'] == 'Masculino'].sum())
print("Total de Mulheres:")
print(dfs_sexo_anosdeestudo[0]['Brasil'][dfs_sexo_anosdeestudo[0]['Sexo'] == 'Feminino'].sum())


print("\nAno de 2014")
print("Total de Homens:")
print(dfs_sexo_anosdeestudo[1]['Brasil'][dfs_sexo_anosdeestudo[0]['Sexo'] == 'Masculino'].sum())
print("Total de Mulheres:")
print(dfs_sexo_anosdeestudo[1]['Brasil'][dfs_sexo_anosdeestudo[0]['Sexo'] == 'Feminino'].sum())

print("\nAno de 2015")
print("Total de Homens:")
print(dfs_sexo_anosdeestudo[2]['Brasil'][dfs_sexo_anosdeestudo[0]['Sexo'] == 'Masculino'].sum())
print("Total de Mulheres:")
print(dfs_sexo_anosdeestudo[2]['Brasil'][dfs_sexo_anosdeestudo[0]['Sexo'] == 'Feminino'].sum())
# Out:
# Ano de 2013
# Total de Homens:
# 41172.767
# Total de Mulheres:
# 44399.292
#
# Ano de 2014
# Total de Homens:
# 45580.367
# Total de Mulheres:
# 49775.708
#
# Ano de 2015
# Total de Homens:
# 48591.545999999995
# Total de Mulheres:
# 53491.544

# %% [markdown]
# ### Graficos

# %% [markdown]
# ### Grafico Sexo X Anos de estudo em 2013

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dfs_sexo_anosdeestudo[0], x='Brasil', y='Grupo de anos de estudos',palette="Set2",hue = "Sexo", orient='h')
g.set_xlabel('Sexo X Anos de estudo')
plt.show()

# %% [markdown]
# ## Regressão Linear

# %% [markdown]
# #### Verificando a matriz de coeficiente de pearson

# %%
df1 = dfs_sexo_anosdeestudo[0].copy()
df2 = dfs_sexo_anosdeestudo[1].copy()
df3 = dfs_sexo_anosdeestudo[2].copy()
df1.insert(8,"Ano",2013)
df2.insert(8,"Ano",2014)
df3.insert(8,"Ano",2015)
ndf = pd.concat([df1,df2,df3], sort=False)
temp = ndf.copy()
temp['Grupo de anos de estudos'] = ndf['Grupo de anos de estudos'].astype('category')
temp['Sexo'] = ndf['Sexo'].astype('category')
temp = pd.get_dummies(temp)
correlation = temp.corr()
matrix = np.triu(temp.corr())
plt.figure(figsize=(20,20))
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True, center=0, cmap='coolwarm', mask=matrix)

# %% [markdown]
# #### Utilizando Regressão para prever os dados em anos futuros

# %%
from traitlets.traitlets import default
from sklearn.linear_model import LinearRegression


#Remodelando os dados para regressão

temp = ndf.copy()
temp['Grupo de anos de estudos'] = ndf['Grupo de anos de estudos'].astype('category')
temp['Sexo'] = ndf['Sexo'].astype('category')
temp = pd.get_dummies(temp)


def retornaGrupos(x):
  lista = {        
      0: "Grupo de anos de estudos_Sem instrução e menos de 1 ano",
      1: "Grupo de anos de estudos_1 a 3 anos",
      2: "Grupo de anos de estudos_4 a 7 anos",
      3: "Grupo de anos de estudos_8 a 10 anos",
      4: "Grupo de anos de estudos_11 a 14 anos",
      5: "Grupo de anos de estudos_15 anos ou mais",
      6: "Grupo de anos de estudos_Não determinados",
  }
  return lista.get(x,default)


def retornaSexo(x):
  lista = {
      0: 'Sexo_Feminino',
      1: 'Sexo_Masculino'
  }
  return lista.get(x,default)


#Renomeando as colunas do df

def renomearGrupos(x):
  lista = {
      0: "Sem instrução e menos de 1 ano",
      1: "1 a 3 anos",
      2: "4 a 7 anos",
      3: "8 a 10 anos",
      4: "11 a 14 anos",
      5: "15 anos ou mais",
      6: "Não determinados",
  }
  return lista.get(x,default)

def renomearSexo(x):
  lista = {
      0: "Feminino",
      1: "Masculino",
    }
  return lista.get(x,default)

#Calcular dado a partir de seus coeficientes.

def calcula(ano,coef1,grupo,coef2,sexo,coef3,interc):
  return interc + ano * coef1 + grupo *coef2 + sexo * coef3

#Aplicando regressão linear 

def aplicarRegressao(df,ldf,col,ano,grupo,sexo):
  X = df[['Ano',retornaGrupos(grupo),retornaSexo(sexo)]]
  Y = df[col]
  lm = LinearRegression()
  lm.fit(X, Y)
  #print("grupo ",grupo," sexo",sexo, "coef ", lm.coef_)
  return calcula(ano,lm.coef_[0],1,lm.coef_[1],1,lm.coef_[2],lm.intercept_)

#Utilização de regressão para criação de um novo dataframe.

def regressao(df,ano,cols):
  ldf = []
  data = []
  for i in range(2):
    for j in range(7):
      ldf.append(j)  
      for col in cols :
        ldf.append(aplicarRegressao(df,ldf,col,ano,j,i))
      ldf.append(i)
      ldf.append(ano)
      data.append(ldf)
      ldf = []
  rdf = pd.DataFrame(data, columns=['Grupo de anos de estudos','Brasil','Norte','Nordeste','Sudeste','Sul','Centro-Oeste','Sexo','Ano'])    
  rdf['Grupo de anos de estudos'] = rdf['Grupo de anos de estudos'].apply(lambda x: renomearGrupos(x))
  rdf['Sexo'] = rdf['Sexo'].apply(lambda x: renomearSexo(x))  
  return rdf

#Obtendo Dataframe a partir da regressão para o ano de 2016 e 2017.

cols = ['Brasil','Norte','Nordeste','Sudeste','Sul','Centro-Oeste']
df2016 = regressao(temp,2016,cols)
df2017 = regressao(temp,2017,cols)

# %% [markdown]
# #### Exibindo os novos dataframes previstos a partir da regressão para os anos de 2016 e 2017

# %%
df2016
# Out:
#           Grupo de anos de estudos        Brasil        Norte     Nordeste  \
# 0   Sem instrução e menos de 1 ano   1938.792071   150.331405   497.020405
# 1                       1 a 3 anos   3282.498238   242.428071   854.997238
# 2                       4 a 7 anos  10032.342571   715.966571  2478.318071
# 3                      8 a 10 anos  10616.289405   766.065905  2369.430738
# 4                     11 a 14 anos  20994.801738  1390.368905  4496.822738
# 5                  15 anos ou mais   9090.125405   511.962071  1636.283405
# 6                 Não determinados   1522.847405   122.320405   420.258905
# 7   Sem instrução e menos de 1 ano   1352.036643   108.566024   296.647690
# 8                       1 a 3 anos   2695.742810   200.662690   654.624524
# 9                       4 a 7 anos   9445.587143   674.201190  2277.945357
# 10                     8 a 10 anos  10029.533976   724.300524  2169.058024
# 11                    11 a 14 anos  20408.046310  1348.603524  4296.450024
# 12                 15 anos ou mais   8503.369976   470.196690  1435.910690
# 13                Não determinados    936.091976    80.555024   219.886190
#
#          Sudeste          Sul  Centro-Oeste       Sexo   Ano
# 0     846.513214   273.035571    171.891476   Feminino  2016
# 1    1441.974048   456.710071    286.388810   Feminino  2016
# 2    4474.266381  1500.208738    863.582810   Feminino  2016
# 3    4930.956214  1683.168238    866.668310   Feminino  2016
# 4   10352.257048  3112.089405   1643.263643   Feminino  2016
# 5    4670.920881  1441.689238    829.269810   Feminino  2016
# 6     648.421214   201.291238    130.555643   Feminino  2016
# 7     593.232214   219.587190    134.003524  Masculino  2016
# 8    1188.693048   403.261690    248.500857  Masculino  2016
# 9    4220.985381  1446.760357    825.694857  Masculino  2016
# 10   4677.675214  1629.719857    828.780357  Masculino  2016
# 11  10098.976048  3058.641024   1605.375690  Masculino  2016
# 12   4417.639881  1388.240857    791.381857  Masculino  2016
# 13    395.140214   147.842857     92.667690  Masculino  2016

# %%
df2017
# Out:
#           Grupo de anos de estudos        Brasil        Norte     Nordeste  \
# 0   Sem instrução e menos de 1 ano   2528.471750   198.130762   648.883012
# 1                       1 a 3 anos   3872.177917   290.227429  1006.859845
# 2                       4 a 7 anos  10622.022250   763.765929  2630.180679
# 3                      8 a 10 anos  11205.969083   813.865262  2521.293345
# 4                     11 a 14 anos  21584.481417  1438.168262  4648.685345
# 5                  15 anos ou mais   9679.805083   559.761429  1788.146012
# 6                 Não determinados   2112.527083   170.119762   572.121512
# 7   Sem instrução e menos de 1 ano   1941.716321   156.365381   448.510298
# 8                       1 a 3 anos   3285.422488   248.462048   806.487131
# 9                       4 a 7 anos  10035.266821   722.000548  2429.807964
# 10                     8 a 10 anos  10619.213655   772.099881  2320.920631
# 11                    11 a 14 anos  20997.725988  1396.402881  4448.312631
# 12                 15 anos ou mais   9093.049655   517.996048  1587.773298
# 13                Não determinados   1525.771655   128.354381   371.748798
#
#          Sudeste          Sul  Centro-Oeste       Sexo   Ano
# 0    1101.354571   353.886179    226.217226   Feminino  2017
# 1    1696.815405   537.560679    340.714560   Feminino  2017
# 2    4729.107738  1581.059345    917.908560   Feminino  2017
# 3    5185.797571  1764.018845    920.994060   Feminino  2017
# 4   10607.098405  3192.940012   1697.589393   Feminino  2017
# 5    4925.762238  1522.539845    883.595560   Feminino  2017
# 6     903.262571   282.141845    184.881393   Feminino  2017
# 7     848.073571   300.437798    188.329274  Masculino  2017
# 8    1443.534405   484.112298    302.826607  Masculino  2017
# 9    4475.826738  1527.610964    880.020607  Masculino  2017
# 10   4932.516571  1710.570464    883.106107  Masculino  2017
# 11  10353.817405  3139.491631   1659.701440  Masculino  2017
# 12   4672.481238  1469.091464    845.707607  Masculino  2017
# 13    649.981571   228.693464    146.993440  Masculino  2017

# %% [markdown]
# #### Exibindo Gráficos para comparação com os demais dados do Dataframe

# %%
dftodosanos = pd.concat([ndf,df2016,df2017], sort=False)
plt.figure(figsize=(10,10))
groupAnos_de_estudo = dftodosanos.groupby('Ano').sum().reset_index()
g=sns.barplot(data=groupAnos_de_estudo, x='Ano', y='Brasil',palette="Paired", orient='v')
g.set_ylabel('Usuários de internet no Brasil')
g.set(title='Número de usuário de Internet por Ano')
plt.show()

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dftodosanos, x='Brasil', y='Grupo de anos de estudos',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Usuários de internet no Brasil')
g.set(title='Número de usuário de Internet por Grupo de anos de estudos')
plt.show()

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dftodosanos[dftodosanos['Ano'] == 2016], x='Sudeste', y='Grupo de anos de estudos',palette="Set2",hue = "Sexo", orient='h')
g.set_xlabel('Usuários de internet no Brasil')
g.set(title='Número de usuário de Internet por Grupo de anos de estudos e Sexo no Ano de 2016')
plt.show()

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dftodosanos[dftodosanos['Ano'] == 2017], x='Sudeste', y='Grupo de anos de estudos',palette="Set2",hue = "Sexo", orient='h')
g.set_xlabel('Usuários de internet no Brasil')
g.set(title='Número de usuário de Internet por Grupo de anos de estudos e Sexo no Ano de 2017')
plt.show()

# %% [markdown]
# # Dataframe da Utilização da Internet segundo sexo e nível de instrução.

# %% [markdown]
# ### Leitura das tabelas:

# %%
df_nivel_instrucao = []
def ler(arquivos, df):
    for arq in arquivos:
        dfInstrucao = pd.read_excel(arq, sheet_name="Tab 1.1.9.1 e 1.1.9.3", usecols="A:G", header=4)
        df.append(dfInstrucao)

ler(arquivos, df_nivel_instrucao)
df_nivel_instrucao[1] #tabela de 2014
# Out:
#                                            Unnamed: 0  Unnamed: 1     Norte  \
# 0                                               Total   95356.075  6412.201
# 1                                       Sem instrução     804.274    69.417
# 2                              Fundamental incompleto   21099.810  1521.004
# 3                                Fundamental completo    9123.747   610.017
# 4                                    Médio incompleto    9275.502   728.988
# 5                                      Médio completo   31025.823  2117.373
# 6                                 Superior incompleto    7645.937   531.536
# 7                                   Superior completo   16125.956   815.752
# 8                                     Não determinado     255.026    18.114
# 9                                              Homens   45580.367  3067.032
# 10                                      Sem instrução     425.117    38.932
# 11                             Fundamental incompleto   11044.512   824.808
# 12                               Fundamental completo    4718.311   307.335
# 13                                   Médio incompleto    4557.779   358.663
# 14                                     Médio completo   14603.521   965.685
# 15                                Superior incompleto    3497.787   230.340
# 16                                  Superior completo    6610.821   332.290
# 17                                    Não determinado     122.519     8.979
# 18                                           Mulheres   49775.708  3345.169
# 19                                      Sem instrução     379.157    30.485
# 20                             Fundamental incompleto   10055.298   696.196
# 21                               Fundamental completo    4405.436   302.682
# 22                                   Médio incompleto    4717.723   370.325
# 23                                     Médio completo   16422.302  1151.688
# 24                                Superior incompleto    4148.150   301.196
# 25                                  Superior completo    9515.135   483.462
# 26                                    Não determinado     132.507     9.135
# 27                                                NaN         NaN       NaN
# 28  Fonte: IBGE, Diretoria de Pesquisas, Coordenaç...         NaN       NaN
#
#      Nordeste    Sudeste        Sul  Centro-Oeste
# 0   20144.488  46107.871  14841.161      7850.354
# 1     155.954    342.791    150.770        85.342
# 2    5202.845   9312.289   3201.367      1862.305
# 3    1788.415   4374.865   1628.685       721.765
# 4    2217.548   4170.702   1382.076       776.188
# 5    6655.233  15496.532   4495.515      2261.170
# 6    1582.428   3559.837   1292.212       679.924
# 7    2469.615   8775.492   2620.288      1444.809
# 8      72.450     75.363     70.248        18.851
# 9    9304.548  22156.695   7238.014      3814.078
# 10     89.786    169.931     77.746        48.722
# 11   2714.340   4806.126   1689.692      1009.546
# 12    886.730   2255.620    879.437       389.189
# 13   1040.212   2061.598    713.152       384.154
# 14   2990.744   7415.746   2166.093      1065.253
# 15    650.626   1679.701    616.298       320.822
# 16    899.205   3732.180   1058.359       588.787
# 17     32.905     35.793     37.237         7.605
# 18  10839.940  23951.176   7603.147      4036.276
# 19     66.168    172.860     73.024        36.620
# 20   2488.505   4506.163   1511.675       852.759
# 21    901.685   2119.245    749.248       332.576
# 22   1177.336   2109.104    668.924       392.034
# 23   3664.489   8080.786   2329.422      1195.917
# 24    931.802   1880.136    675.914       359.102
# 25   1570.410   5043.312   1561.929       856.022
# 26     39.545     39.570     33.011        11.246
# 27        NaN        NaN        NaN           NaN
# 28        NaN        NaN        NaN           NaN

# %% [markdown]
# ### Tratamento das tabelas, de modo a torná-las viável para utilização.
# Aqui tratamos as duas últimas linhas que possuíam dados nulos

# %%
def tratar(df):
    for i in range(len(df)):
        df[i] = df[i].drop(df[i].index[[9, 18, 27, 28]])
        df[i].rename(columns={'Unnamed: 0': 'Sexo e nivel de instrucao', 'Unnamed: 1': 'Brasil'}, inplace=True)
tratar(df_nivel_instrucao)

df_nivel_instrucao[2] #tabela de 2015
# Out:
#    Sexo e nivel de instrucao      Brasil     Norte   Nordeste    Sudeste  \
# 0                      Total  102083.090  6715.311  21831.084  49246.983
# 1              Sem instrução    1113.820    69.813    243.860    497.421
# 2     Fundamental incompleto   22617.735  1586.770   5609.549  10015.739
# 3       Fundamental completo   10111.967   657.403   1967.037   4980.461
# 4           Médio incompleto    9650.797   786.453   2309.745   4368.745
# 5             Médio completo   33631.347  2187.786   7372.022  16812.757
# 6        Superior incompleto    7746.769   557.257   1636.589   3479.595
# 7          Superior completo   16908.158   838.973   2615.289   9010.738
# 8            Não determinado     302.497    30.856     76.993     81.527
# 10             Sem instrução     553.748    37.831    122.688    244.283
# 11    Fundamental incompleto   11672.158   830.174   2984.805   5044.369
# 12      Fundamental completo    5189.625   339.863    997.445   2520.046
# 13          Médio incompleto    4747.110   370.285   1084.286   2178.926
# 14            Médio completo   15766.044  1032.592   3295.932   7922.012
# 15       Superior incompleto    3539.332   240.904    661.986   1695.127
# 16         Superior completo    6980.974   331.166    947.590   3873.241
# 17           Não determinado     142.555    16.812     36.937     37.064
# 19             Sem instrução     560.072    31.982    121.172    253.138
# 20    Fundamental incompleto   10945.577   756.596   2624.744   4971.370
# 21      Fundamental completo    4922.342   317.540    969.592   2460.415
# 22          Médio incompleto    4903.687   416.168   1225.459   2189.819
# 23            Médio completo   17865.303  1155.194   4076.090   8890.745
# 24       Superior incompleto    4207.437   316.353    974.603   1784.468
# 25         Superior completo    9927.184   507.807   1667.699   5137.497
# 26           Não determinado     159.942    14.044     40.056     44.463
#
#           Sul  Centro-Oeste
# 0   15758.972      8530.740
# 1     193.879       108.847
# 2    3445.807      1959.870
# 3    1730.473       776.593
# 4    1373.308       812.546
# 5    4768.842      2489.940
# 6    1308.358       764.970
# 7    2848.000      1595.158
# 8      90.305        22.816
# 10     98.659        50.287
# 11   1769.595      1043.215
# 12    913.772       418.499
# 13    696.906       416.707
# 14   2353.053      1162.455
# 15    624.254       317.061
# 16   1161.601       667.376
# 17     43.378         8.364
# 19     95.220        58.560
# 20   1676.212       916.655
# 21    816.701       358.094
# 22    676.402       395.839
# 23   2415.789      1327.485
# 24    684.104       447.909
# 25   1686.399       927.782
# 26     46.927        14.452

# %% [markdown]
# Criação de uma coluna para Sexo, de modo a melhorar a visualização e facilitar o trabalho.

# %%
def separar(df):
    newdfs = []
    for df in df:
        s = pd.Series([])
        df_instrucao_Homen = df.iloc[9:17]  # Homens
        df_instrucao_Mulher = df.iloc[17:]  # Mulheres
        df_instrucao_Homen.insert(7, "Sexo", "Masculino")
        df_instrucao_Mulher.insert(7, "Sexo", "Feminino")
        df_instrucao_Total = pd.concat([df_instrucao_Mulher, df_instrucao_Homen], sort=False)
        newdfs.append(df_instrucao_Total)
    return newdfs
  
df_nivel_instrucao = separar(df_nivel_instrucao)

df_nivel_instrucao[2] #tabela 2015
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   after removing the cwd from sys.path.
#    Sexo e nivel de instrucao     Brasil     Norte  Nordeste   Sudeste  \
# 19             Sem instrução    560.072    31.982   121.172   253.138
# 20    Fundamental incompleto  10945.577   756.596  2624.744  4971.370
# 21      Fundamental completo   4922.342   317.540   969.592  2460.415
# 22          Médio incompleto   4903.687   416.168  1225.459  2189.819
# 23            Médio completo  17865.303  1155.194  4076.090  8890.745
# 24       Superior incompleto   4207.437   316.353   974.603  1784.468
# 25         Superior completo   9927.184   507.807  1667.699  5137.497
# 26           Não determinado    159.942    14.044    40.056    44.463
# 10             Sem instrução    553.748    37.831   122.688   244.283
# 11    Fundamental incompleto  11672.158   830.174  2984.805  5044.369
# 12      Fundamental completo   5189.625   339.863   997.445  2520.046
# 13          Médio incompleto   4747.110   370.285  1084.286  2178.926
# 14            Médio completo  15766.044  1032.592  3295.932  7922.012
# 15       Superior incompleto   3539.332   240.904   661.986  1695.127
# 16         Superior completo   6980.974   331.166   947.590  3873.241
# 17           Não determinado    142.555    16.812    36.937    37.064
#
#          Sul  Centro-Oeste       Sexo
# 19    95.220        58.560   Feminino
# 20  1676.212       916.655   Feminino
# 21   816.701       358.094   Feminino
# 22   676.402       395.839   Feminino
# 23  2415.789      1327.485   Feminino
# 24   684.104       447.909   Feminino
# 25  1686.399       927.782   Feminino
# 26    46.927        14.452   Feminino
# 10    98.659        50.287  Masculino
# 11  1769.595      1043.215  Masculino
# 12   913.772       418.499  Masculino
# 13   696.906       416.707  Masculino
# 14  2353.053      1162.455  Masculino
# 15   624.254       317.061  Masculino
# 16  1161.601       667.376  Masculino
# 17    43.378         8.364  Masculino

# %% [markdown]
# ### Análise dos dados:
# Média, mediana e desvio padrão

# %%
print("\nAno de 2013")
print(df_nivel_instrucao[0].describe())
print("\nAno de 2014")
print(df_nivel_instrucao[1].describe())
print("\nAno de 2015")
print(df_nivel_instrucao[2].describe())
# Out:
# Ano de 2013
#              Brasil       Norte     Nordeste      Sudeste          Sul  \
# count     16.000000   16.000000    16.000000    16.000000    16.000000
# mean    5348.253688  336.058063  1098.683188  2631.964063   843.447187
# std     4572.060143  285.735552   976.985479  2319.309993   674.426517
# min      108.886000   10.775000    23.256000    31.932000    32.476000
# 25%     2426.035250  154.872500   484.040250  1122.750500   428.318000
# 50%     4057.318500  281.382500   837.747500  1934.260500   661.054000
# 75%     8623.029500  479.311500  1606.818000  4159.148750  1345.165750
# max    14781.275000  929.721000  3186.734000  7461.444000  2123.384000
#
#        Centro-Oeste
# count     16.000000
# mean     438.101187
# std      349.069466
# min        9.094000
# 25%      230.340000
# 50%      343.986500
# 75%      722.317250
# max     1079.992000
#
# Ano de 2014
#              Brasil        Norte     Nordeste      Sudeste          Sul  \
# count     16.000000    16.000000    16.000000    16.000000    16.000000
# mean    5959.754687   400.762563  1259.030500  2881.741937   927.572563
# std     5075.997936   346.077787  1131.951203  2515.092563   739.064348
# min      122.519000     8.979000    32.905000    35.793000    33.011000
# 25%     2729.619500   182.488000   510.416000  1302.990750   481.660000
# 50%     4637.751000   319.812500   916.743500  2114.174500   731.200000
# 75%     9650.175750   536.645500  1799.933750  4581.153750  1524.238500
# max    16422.302000  1151.688000  3664.489000  8080.786000  2329.422000
#
#        Centro-Oeste
# count     16.000000
# mean     490.647125
# std      394.814103
# min        7.605000
# 25%      252.797000
# 50%      386.671500
# 75%      853.574750
# max     1195.917000
#
# Ano de 2015
#              Brasil        Norte     Nordeste      Sudeste         Sul  \
# count     16.000000    16.000000    16.000000    16.000000    16.00000
# mean    6380.193125   419.706938  1364.442750  3077.936438   984.93575
# std     5467.441510   355.819731  1243.680378  2706.938884   787.88682
# min      142.555000    14.044000    36.937000    37.064000    43.37800
# 25%     2794.517000   190.135750   527.161500  1334.629750   492.85525
# 50%     4913.014500   335.514500   986.024000  2325.117000   756.80350
# 75%    10181.782250   570.004250  1906.960250  4989.619750  1678.75875
# max    17865.303000  1155.194000  4076.090000  8890.745000  2415.78900
#
#        Centro-Oeste
# count     16.000000
# mean     533.171250
# std      427.472402
# min        8.364000
# 25%      252.435750
# 50%      417.603000
# 75%      919.436750
# max     1327.485000

# %% [markdown]
# Sexo e nível de instrução que mais utilizam a internet, com o valor total máximo.

# %%
print("\nAno de 2013")
i = df_nivel_instrucao[0][df_nivel_instrucao[0]['Brasil']==df_nivel_instrucao[0]['Brasil'].max()].index[0]
print("Nível de instrução:",df_nivel_instrucao[0]['Sexo e nivel de instrucao'][i])
print("Sexo:",df_nivel_instrucao[0]['Sexo'][i])
print("Valor total:",df_nivel_instrucao[0]['Brasil'][i])

print("\nAno de 2014")
i = df_nivel_instrucao[1][df_nivel_instrucao[1]['Brasil']==df_nivel_instrucao[1]['Brasil'].max()].index[0]
print("Nível de instrução:",df_nivel_instrucao[1]['Sexo e nivel de instrucao'][i])
print("Sexo:",df_nivel_instrucao[1]['Sexo'][i])
print("Valor total:",df_nivel_instrucao[1]['Brasil'][i])

print("\nAno de 2015")
i = df_nivel_instrucao[2][df_nivel_instrucao[2]['Brasil']==df_nivel_instrucao[2]['Brasil'].max()].index[0]
print("Nível de instrução:",df_nivel_instrucao[2]['Sexo e nivel de instrucao'][i])
print("Sexo:",df_nivel_instrucao[2]['Sexo'][i])
print("Valor total:",df_nivel_instrucao[2]['Brasil'][i])
# Out:
# Ano de 2013
# Nível de instrução: Médio completo
# Sexo: Feminino
# Valor total: 14781.275
#
# Ano de 2014
# Nível de instrução: Médio completo
# Sexo: Feminino
# Valor total: 16422.302
#
# Ano de 2015
# Nível de instrução: Médio completo
# Sexo: Feminino
# Valor total: 17865.303

# %% [markdown]
# ### Análise gráfica dos dados:

# %% [markdown]
# Nível de instrução x Usuários de internet no Brasil por sexo em 2013:

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=df_nivel_instrucao[0], x='Brasil', y='Sexo e nivel de instrucao',palette="Set2",hue = "Sexo", orient='h')
g.set_xlabel('Usuários de internet')
plt.show()

# %% [markdown]
# Nível de instrução x Usuários de internet no Brasil por sexo em 2014:

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=df_nivel_instrucao[1], x='Brasil', y='Sexo e nivel de instrucao',palette="Set2",hue = "Sexo", orient='h')
g.set_xlabel('Usuários de internet')
plt.show()

# %% [markdown]
# Nível de instrução x Usuários de internet no Brasil por sexo em 2015:

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=df_nivel_instrucao[2], x='Brasil', y='Sexo e nivel de instrucao',palette="Set2",hue = "Sexo", orient='h')
g.set_xlabel('Usuários de internet')
plt.show()

# %% [markdown]
# Gráfico de Nível de Instrução x Usuários de Internet do Sexo Feminino no Brasil ao longo dos anos:

# %%
newdf1 = df_nivel_instrucao[0].copy()
newdf2 = df_nivel_instrucao[1].copy()
newdf3 = df_nivel_instrucao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)

plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Brasil', y='Sexo e nivel de instrucao',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Nível de Instrução')
plt.show()

# %% [markdown]
# Gráfico de Nível de Instrução x Usuários de Internet do Sexo Masculino no Brasil ao longo dos anos:

# %%
newdf1.drop(newdf1.loc[newdf1['Sexo']=='Feminino'].index, inplace=True)
newdf2.drop(newdf2.loc[newdf2['Sexo']=='Feminino'].index, inplace=True)
newdf3.drop(newdf3.loc[newdf3['Sexo']=='Feminino'].index, inplace=True)
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)

plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Brasil', y='Sexo e nivel de instrucao',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Nível de Instrução')
plt.show()

# %% [markdown]
# # Regressão Linear

# %% [markdown]
# Verificando a matriz de coeficiente de pearson, para medir o grau de relação linear entre cada par de itens do dataframe.

# %%
newdf1 = df_nivel_instrucao[0].copy()
newdf2 = df_nivel_instrucao[1].copy()
newdf3 = df_nivel_instrucao[2].copy()
newdf1.insert(8,"Ano",2013)
newdf2.insert(8,"Ano",2014)
newdf3.insert(8,"Ano",2015)
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)

temp = newdf.copy()
temp['Sexo e nivel de instrucao'] = newdf['Sexo e nivel de instrucao'].astype('category')
temp['Sexo'] = newdf['Sexo'].astype('category')
temp = pd.get_dummies(temp)
correlation = temp.corr()
matrix = np.triu(temp.corr())
plt.figure(figsize=(20,20))
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True, center=0, cmap='coolwarm', mask=matrix)

# %% [markdown]
# Utilizando Regressão para prever os dados em anos futuros

# %%
from traitlets.traitlets import default
from sklearn.linear_model import LinearRegression

#Remodelando os dados para regressão

temp = newdf.copy()
temp['Sexo e nivel de instrucao'] = newdf['Sexo e nivel de instrucao'].astype('category')
temp['Sexo'] = newdf['Sexo'].astype('category')
temp = pd.get_dummies(temp)


def retornaGrupos(x):
  lista = {
      0: "Sexo e nivel de instrucao_Sem instrução",
      1: "Sexo e nivel de instrucao_Fundamental incompleto",
      2: "Sexo e nivel de instrucao_Fundamental completo",
      3: "Sexo e nivel de instrucao_Médio incompleto",
      4: "Sexo e nivel de instrucao_Médio completo",
      5: "Sexo e nivel de instrucao_Superior incompleto",
      6: "Sexo e nivel de instrucao_Superior completo",
      7: "Sexo e nivel de instrucao_Não determinado",
  }
  return lista.get(x,default)


def retornaSexo(x):
  lista = {
      0: 'Sexo_Feminino',
      1: 'Sexo_Masculino'
  }
  return lista.get(x,default)


#Renomeando as colunas do df

def renomearGrupos(x):
  lista = {
      0: "Sem instrução",	
      1: "Fundamental incompleto",
      2: "Fundamental completo", 
      3: "Médio incompleto",
      4: "Médio completo",
      5: "Superior incompleto",
      6: "Superior completo",	
      7: "Não determinado",
  }
  return lista.get(x,default)

def renomearSexo(x):
  lista = {
      0: "Feminino",
      1: "Masculino",
    }
  return lista.get(x,default)

#Calcular dado a partir de seus coeficientes.

def calcula(ano,coef1,grupo,coef2,sexo,coef3,interc):
  return interc + ano * coef1 + grupo *coef2 + sexo * coef3

#Aplicando regressão linear 

def aplicarRegressao(df,ldf,col,ano,grupo,sexo):
  X = df[['Ano',retornaGrupos(grupo),retornaSexo(sexo)]]
  Y = df[col]
  lm = LinearRegression()
  lm.fit(X, Y)
  #print("grupo ",grupo," sexo",sexo, "coef ", lm.coef_)
  return calcula(ano,lm.coef_[0],1,lm.coef_[1],1,lm.coef_[2],lm.intercept_)

#Utilização de regressão para criação de um novo dataframe.

def regressao(df,ano,cols):
  ldf = []
  data = []
  for i in range(2):
    for j in range(8):
      ldf.append(j)  
      for col in cols :
        ldf.append(aplicarRegressao(df,ldf,col,ano,j,i))
      ldf.append(i)
      ldf.append(ano)
      data.append(ldf)
      ldf = []
  rdf = pd.DataFrame(data, columns=['Sexo e nivel de instrucao','Brasil','Norte','Nordeste','Sudeste','Sul','Centro-Oeste','Sexo','Ano'])    
  rdf['Sexo e nivel de instrucao'] = rdf['Sexo e nivel de instrucao'].apply(lambda x: renomearGrupos(x))
  rdf['Sexo'] = rdf['Sexo'].apply(lambda x: renomearSexo(x))  
  return rdf

#Obtendo Dataframe a partir da regressão para o ano de 2016 e 2017.

cols = ['Brasil','Norte','Nordeste','Sudeste','Sul','Centro-Oeste']
df2016 = regressao(temp,2016,cols)
df2017 = regressao(temp,2017,cols)

# %% [markdown]
# Exibindo o novo dataframe com a previsão para 2016

# %%
df2016
# Out:
#    Sexo e nivel de instrucao        Brasil        Norte     Nordeste  \
# 0              Sem instrução   1754.699937   135.771229   446.531458
# 1     Fundamental incompleto  11662.594771   827.710396  2879.124292
# 2       Fundamental completo   5836.801604   390.385729  1231.520958
# 3           Médio incompleto   5797.782271   455.861396  1423.152458
# 4             Médio completo  16758.042438  1113.969396  3666.612958
# 5        Superior incompleto   4987.152604   361.682729  1126.128125
# 6          Superior completo   9260.192771   499.479729  1592.809792
# 7            Não determinado   1420.430438   114.582729   387.251458
# 8              Sem instrução   1241.288938    99.226521   271.205333
# 9     Fundamental incompleto  11149.183771   791.165687  2703.798167
# 10      Fundamental completo   5323.390604   353.841021  1056.194833
# 11          Médio incompleto   5284.371271   419.316688  1247.826333
# 12            Médio completo  16244.631438  1077.424688  3491.286833
# 13       Superior incompleto   4473.741604   325.138021   950.802000
# 14         Superior completo   8746.781771   462.935021  1417.483667
# 15           Não determinado    907.019438    78.038021   211.925333
#
#         Sudeste          Sul  Centro-Oeste       Sexo   Ano
# 0    766.972813   249.482396    155.942042   Feminino  2016
# 1   5203.392979  1745.621729   1006.745375   Feminino  2016
# 2   2785.713146   963.184062    465.997708   Feminino  2016
# 3   2594.549479   835.209729    489.009208   Feminino  2016
# 4   8327.095979  2404.700563   1245.663542   Feminino  2016
# 5   2237.578979   797.644229    464.118542   Feminino  2016
# 6   4856.204979  1469.199729    842.498542   Feminino  2016
# 7    593.800646   203.150063    121.645542   Feminino  2016
# 8    545.351938   202.715062    122.790083  Masculino  2016
# 9   4981.772104  1698.854396    973.593417  Masculino  2016
# 10  2564.092271   916.416729    432.845750  Masculino  2016
# 11  2372.928604   788.442396    455.857250  Masculino  2016
# 12  8105.475104  2357.933229   1212.511583  Masculino  2016
# 13  2015.958104   750.876896    430.966583  Masculino  2016
# 14  4634.584104  1422.432396    809.346583  Masculino  2016
# 15   372.179771   156.382729     88.493583  Masculino  2016

# %% [markdown]
# Exibindo o novo dataframe com a previsão para 2017

# %%
df2017
# Out:
#    Sexo e nivel de instrucao        Brasil        Norte     Nordeste  \
# 0              Sem instrução   2270.669656   177.595667   579.411240
# 1     Fundamental incompleto  12178.564490   869.534833  3012.004073
# 2       Fundamental completo   6352.771323   432.210167  1364.400740
# 3           Médio incompleto   6313.751990   497.685833  1556.032240
# 4             Médio completo  17274.012156  1155.793833  3799.492740
# 5        Superior incompleto   5503.122323   403.507167  1259.007906
# 6          Superior completo   9776.162490   541.304167  1725.689573
# 7            Não determinado   1936.400156   156.407167   520.131240
# 8              Sem instrução   1757.258656   141.050958   404.085115
# 9     Fundamental incompleto  11665.153490   832.990125  2836.677948
# 10      Fundamental completo   5839.360323   395.665458  1189.074615
# 11          Médio incompleto   5800.340990   461.141125  1380.706115
# 12            Médio completo  16760.601156  1119.249125  3624.166615
# 13       Superior incompleto   4989.711323   366.962458  1083.681781
# 14         Superior completo   9262.751490   504.759458  1550.363448
# 15           Não determinado   1422.989156   119.862458   344.805115
#
#         Sudeste          Sul  Centro-Oeste       Sexo   Ano
# 0    989.959000   320.226677    203.477073   Feminino  2017
# 1   5426.379167  1816.366010   1054.280406   Feminino  2017
# 2   3008.699333  1033.928344    513.532740   Feminino  2017
# 3   2817.535667   905.954010    536.544240   Feminino  2017
# 4   8550.082167  2475.444844   1293.198573   Feminino  2017
# 5   2460.565167   868.388510    511.653573   Feminino  2017
# 6   5079.191167  1539.944010    890.033573   Feminino  2017
# 7    816.786833   273.894344    169.180573   Feminino  2017
# 8    768.338125   273.459344    170.325115  Masculino  2017
# 9   5204.758292  1769.598677   1021.128448  Masculino  2017
# 10  2787.078458   987.161010    480.380781  Masculino  2017
# 11  2595.914792   859.186677    503.392281  Masculino  2017
# 12  8328.461292  2428.677510   1260.046615  Masculino  2017
# 13  2238.944292   821.621177    478.501615  Masculino  2017
# 14  4857.570292  1493.176677    856.881615  Masculino  2017
# 15   595.165958   227.127010    136.028615  Masculino  2017

# %% [markdown]
# Exibindo Gráficos para comparação com os demais dados do Dataframe

# %%
dftodosanos = pd.concat([newdf,df2016,df2017], sort=False)
plt.figure(figsize=(10,10))
g=sns.barplot(data=dftodosanos, x='Brasil', y='Sexo e nivel de instrucao',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Nível de instrução')
g.set_xlabel('Quantidade de usuários')
g.set(title='Quantidade de usuário de Internet por nível de instrução')
plt.show()

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dftodosanos[dftodosanos['Ano'] == 2016], x='Brasil', y='Sexo e nivel de instrucao',palette="Set1",hue = "Sexo", orient='h')
g.set_ylabel('Nível de instrução')
g.set_xlabel('Quantidade de usuários')
g.set(title='Quantidade de usuários de internet de acordo com nível de instrução no Ano de 2016')
plt.show()

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dftodosanos[dftodosanos['Ano'] == 2017], x='Brasil', y='Sexo e nivel de instrucao',palette="Set1",hue = "Sexo", orient='h')
g.set_ylabel('Nível de instrução')
g.set_xlabel('Quantidade de usuários')
g.set(title='Quantidade de usuários de internet de acordo com nível de instrução no Ano de 2017')
plt.show()

# %% [markdown]
# # Renda e Profissão

# %%
# !wget https://raw.githubusercontent.com/saulo-miranda/Projeto-CCF425-Acesso-a-internet-e-posse-de-celular/main/xls/2013.xls -O 2013.xls
# !wget https://raw.githubusercontent.com/saulo-miranda/Projeto-CCF425-Acesso-a-internet-e-posse-de-celular/main/xls/2014.xlsx -O 2014.xlsx
# !wget https://raw.githubusercontent.com/saulo-miranda/Projeto-CCF425-Acesso-a-internet-e-posse-de-celular/main/xls/2015.xlsx -O 2015.xlsx
# Out:
# --2022-07-26 02:53:33--  https://raw.githubusercontent.com/saulo-miranda/Projeto-CCF425-Acesso-a-internet-e-posse-de-celular/main/xls/2013.xls
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 565760 (552K) [application/octet-stream]
# Saving to: ‘2013.xls’
#
# 2013.xls            100%[===================>] 552.50K  --.-KB/s    in 0.04s
#
# 2022-07-26 02:53:33 (12.8 MB/s) - ‘2013.xls’ saved [565760/565760]

# %% [markdown]
# ### Funções para filtrar e separar dataframes

# %%
def filtrar_tabelas(arquivos, tabela, prefixo, linhas, nome_coluna):
  anos = ['2015', '2014', '2013']
  for f in arquivos:
    df = pd.read_excel(f, sheet_name=tabela, usecols='A:G')
    df.columns = [nome_coluna, "Brasil", "Norte","Nordeste","Sudeste","Sul","Centro-Oeste"]
    df2 = df
    df = df.drop(df.index[[0,1,2,3]])
    df = df[df.index < linhas]
    df.to_csv('/content/'+prefixo+anos.pop()+'.csv')

# %%
def separar_dataframes(csvs, limites):
  dfs = []
  for c in csvs:  
    df = pd.read_csv(c)
    df = df.drop(columns=['Unnamed: 0'])
    df_u = df.iloc[limites[1]:limites[2]:]
    df_n = df.iloc[limites[2]:,:]
    df_u.insert(7, 'Utilizaram', 'Sim')
    df_n.insert(7, 'Utilizaram', 'Nao')
    df_total = pd.concat([df_u, df_n], sort=False)
    df_total = df_total.drop(df_total.index[[limites[0],limites[1]]])
    dfs.append(df_total)
  return dfs

# %% [markdown]
# ### Função para recuperar profissoes que mais usaram internet por região

# %%
def mais_usaram_regiao(dfs, regioes):
  retorno = []
  for d in dfs:
    for r in regioes:
      i = d[d['Utilizaram'] == 'Sim']
      i = i[i[r]==i[r].max()].index[0]
      retorno.append(d['Profissao'][i])
  return retorno

# %%
filtrar_tabelas(['2013.xls', '2014.xlsx', '2015.xlsx'], "Tab 1.1.16.1 e 1.1.16.2", '16_', 37, "Profissao")
filtrar_tabelas(['2013.xls', '2014.xlsx', '2015.xlsx'], "Tabela 1.1.19.1 e 1.1.19.2", '19_', 34, "Renda")

# %%
dfs_profissao = separar_dataframes(['16_2013.csv', '16_2014.csv', '16_2015.csv'], [0,11,22])
dfs_renda = separar_dataframes(['19_2013.csv', '19_2014.csv', '19_2015.csv'], [0,10,20])
display(dfs_profissao[0])

# %%
profissoes = mais_usaram_regiao(dfs_profissao, ['Sul', 'Sudeste', 'Nordeste', 'Norte', 'Centro-Oeste'])
print(profissoes)

# %% [markdown]
# ### Informações sobre os dados e alguns reparos
#
# ---

# %%
dfs_renda[0].dtypes
display(dfs_renda[0])

# %%
dfs_profissao[0].dtypes

# %%
dfs_profissao[0]['Norte'].replace(['-'], 0, inplace=True)
dfs_profissao[0]['Centro-Oeste'].replace(['-'], 0, inplace=True)
dfs_profissao[2]['Norte'].replace(['-'], 0, inplace=True)
dfs_profissao[2]['Centro-Oeste'].replace(['-'], 0, inplace=True)

# %% [markdown]
# ### Média, Moda e Mediana da renda

# %%
print("\nAno de 2013")
print(dfs_renda[0].describe())
print("\nAno de 2014")
print(dfs_renda[1].describe())
print("\nAno de 2015")
print(dfs_renda[2].describe())

# %% [markdown]
# ### Média, Moda e Mediana da Profissão

# %%
print("\nAno de 2013")
print(dfs_profissao[0].describe())
print("\nAno de 2014")
print(dfs_profissao[1].describe())
print("\nAno de 2015")
print(dfs_profissao[2].describe())

# %% [markdown]
# ### Grupo de renda que mais utilizou a internet em cada ano

# %%
print("\nAno de 2013")
i = dfs_renda[0][dfs_renda[0]['Utilizaram'] == 'Sim']
i = i[i['Brasil']==i['Brasil'].max()].index[0]
print(dfs_renda[0]['Renda'][i])
print("\nAno de 2014")
i = dfs_renda[1][dfs_renda[1]['Utilizaram'] == 'Sim']
i = i[i['Brasil']==i['Brasil'].max()].index[0]
print(dfs_renda[1]['Renda'][i])
print("\nAno de 2015")
i = dfs_renda[2][dfs_renda[2]['Utilizaram'] == 'Sim']
i = i[i['Brasil']==i['Brasil'].max()].index[0]
print(dfs_renda[2]['Renda'][i])

# %% [markdown]
# ### Grupo de profissões que mais utilizou a internet

# %%
print("\nAno de 2013")
i = dfs_profissao[0][dfs_profissao[0]['Utilizaram'] == 'Sim']
i = i[i['Brasil']==i['Brasil'].max()].index[0]
print(dfs_profissao[0]['Profissao'][i])
print("\nAno de 2014")
i = dfs_profissao[1][dfs_profissao[1]['Utilizaram'] == 'Sim']
i = i[i['Brasil']==i['Brasil'].max()].index[0]
print(dfs_profissao[1]['Profissao'][i])
print("\nAno de 2015")
i = dfs_profissao[2][dfs_profissao[2]['Utilizaram'] == 'Sim']
i = i[i['Brasil']==i['Brasil'].max()].index[0]
print(dfs_profissao[2]['Profissao'][i])

# %% [markdown]
# ## Gráficos renda

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dfs_renda[0][dfs_renda[0]['Utilizaram']=='Sim'], x='Brasil', y='Renda',palette="pastel", orient='h')
g.set_xlabel('Usuários de internet no Brasil por renda')
g.set_title('Usuários X Renda')
plt.show()

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dfs_renda[0], x='Brasil', y='Renda',palette="Set2",hue = "Utilizaram", orient='h')
g.set_xlabel('Usuários')
g.set_title('Usuários e não-usuários X Renda')
plt.show()

# %%
newdf1 = dfs_renda[0].copy()
newdf2 = dfs_renda[1].copy()
newdf3 = dfs_renda[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
newdf = newdf[newdf['Utilizaram']=='Sim']
plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Brasil', y='Renda',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Renda')
g.set_xlabel('Usuários')
g.set_title('Usuários de internet no Brasil por Renda (2013-2015)')
plt.show()

# %% [markdown]
# ## Gráficos Profissão

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dfs_profissao[0][dfs_profissao[0]['Utilizaram']=='Sim'], x='Brasil', y='Profissao',palette="pastel", orient='h')
g.set_xlabel('Usuários')
g.set_ylabel('Profissão')
g.set_title('Usuários de internet no Brasil por Profissão - 2013')
plt.show()

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=dfs_profissao[0], x='Brasil', y='Profissao',palette="Set2",hue = "Utilizaram", orient='h')
g.set_xlabel('Usuários')
g.set_title('Usuários e não-usuários X Profissão')
plt.show()

# %%
newdf1 = dfs_profissao[0].copy()
newdf2 = dfs_profissao[1].copy()
newdf3 = dfs_profissao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
newdf = newdf[newdf['Utilizaram']=='Sim']
plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Brasil', y='Profissao',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Profissao')
g.set_xlabel('Usuários')
g.set_title('Usuários de internet no Brasil x Profissão (2013-2015)')
plt.show()

# %% [markdown]
# # Perguntas

# %% [markdown]
# **1 - Qual a região que possui mais pessoas acessando a internet?**
#
# Sudeste ,conforme mostra o gráfico abaixo

# %%
newdf1 = dfs_idade_regiao[0].copy()
newdf2 = dfs_idade_regiao[1].copy()
newdf3 = dfs_idade_regiao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
plt.figure(figsize=(10,10))
groupIdades = newdf.groupby('Ano').sum().reset_index()
groupIdades2 = groupIdades.drop(columns=["Brasil"]) 
g=sns.barplot(data=groupIdades2,palette="Paired", orient='v')
g.set_ylabel('Usuários de internet no Brasil')
plt.show()

# %% [markdown]
# **2 - Qual a idade que mais acessa a internet?**
#
# 20-24 anos, conforme podemos notar no gráfico abaixo , e conferir com o código seguinte

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Brasil', y='Grupo de Idades',palette="Set3",hue= "Ano" ,orient='h')
g.set_ylabel('Usuários de internet no Brasil')
plt.show()
print("\nAno de 2013")
i = dfs_idade_regiao[0][dfs_idade_regiao[0]['Brasil']==dfs_idade_regiao[0]['Brasil'].max()].index[0]
print(dfs_idade_regiao[0]['Grupo de Idades'][i])
print("\nAno de 2014")
i = dfs_idade_regiao[1][dfs_idade_regiao[1]['Brasil']==dfs_idade_regiao[1]['Brasil'].max()].index[0]
print(dfs_idade_regiao[1]['Grupo de Idades'][i])
print("\nAno de 2015")
i = dfs_idade_regiao[2][dfs_idade_regiao[2]['Brasil']==dfs_idade_regiao[2]['Brasil'].max()].index[0]
print(dfs_idade_regiao[2]['Grupo de Idades'][i])

# %% [markdown]
# **3 - Quais as ocupações(categoria de emprego) que mais acessaram a internet em cada região?**
#
# Observando os gráficos abaixo, temos que as categorias de emprego por região são:
#
# **Sudeste** - Trabalhadores da produção de bens e serviços e de reparação e manutenção
#
# **Sul** - Trabalhadores da produção de bens e serviços e de reparação e manutenção
#
# **Nordeste** - Trabalhadores da produção de bens e serviços e de reparação e manutenção e Trabalhadores dos serviços (valores muito próximos)
#
# **Norte** - Trabalhadores da produção de bens e serviços e de reparação e manutenção
#
# **Centro-Oeste** - Trabalhadores da produção de bens e serviços e de reparação e manutenção

# %%
newdf1 = dfs_profissao[0].copy()
newdf2 = dfs_profissao[1].copy()
newdf3 = dfs_profissao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
newdf = newdf[newdf['Utilizaram']=='Sim']

plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Sudeste', y='Profissao',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Profissao')
g.set_xlabel('Usuários na região')
g.set_title('Usuários de internet na região sudeste x Profissão (2013-2015)')
plt.show()

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Sul', y='Profissao',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Profissao')
g.set_xlabel('Usuários na região sul')
g.set_title('Usuários de internet na região sul x Profissão (2013-2015)')
plt.show()

# %%
plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Nordeste', y='Profissao',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Profissao')
g.set_xlabel('Usuários na região Nordeste')
g.set_title('Usuários de internet na região Nordeste x Profissão (2013-2015)')
plt.show()

# %%
newdf['Norte'] = newdf['Norte'].astype(float)

plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Norte', y='Profissao',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Profissao')
g.set_xlabel('Usuários na região Norte')
g.set_title('Usuários de internet na região Norte x Profissão (2013-2015)')
plt.show()

# %%
newdf['Centro-Oeste'] = newdf['Centro-Oeste'].astype(float)

plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Centro-Oeste', y='Profissao',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Profissao')
g.set_xlabel('Usuários na região Centro-Oeste')
g.set_title('Usuários de internet na região Centro-Oeste x Profissão (2013-2015)')
plt.show()

# %% [markdown]
# **4 - Com o passar dos anos, a porcentagem de usuarios de internet em cada região mudou?**
#
#
# Não, como podemos ver no gráfico abaixo, houve pouca variação ao olharmos para a porcentagem de pessoas que usam internet em cada região.

# %%
newdf1 = dfs_idade_regiao[0].copy()
newdf2 = dfs_idade_regiao[1].copy()
newdf3 = dfs_idade_regiao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
group = newdf.groupby('Ano').sum().reset_index()

regiaodf = newdf.groupby('Ano').sum().reset_index()

regioes = ['Centro-Oeste', 'Nordeste', 'Norte', 'Sudeste', 'Sul']
anos = ["2013", "2014", "2015"]
def filtro_regiao_ano(v_regiao, v_ano, group):
  arr_anos = []
  arr_usuarios = []
  group.set_index('Ano', inplace=True)
  for a in v_ano:
    for r in v_regiao:
      arr_usuarios.append(group.at[a,r]/group.at[a,'Brasil'])
      arr_anos.append(a)
  return arr_anos, arr_usuarios

r_anos, r_usuarios = filtro_regiao_ano(regioes, anos, regiaodf)


df_regioes = pd.DataFrame()
df_regioes['Regioes'] = regioes + regioes + regioes
df_regioes['Usuarios'] = r_usuarios
df_regioes['Anos'] = r_anos
df_regioes = df_regioes.sort_values(by='Usuarios')
plt.figure(figsize=(10,10))
g=sns.barplot(data=df_regioes, y='Regioes', x='Usuarios',palette="Set1",hue= "Anos" ,orient='h')
g.set_ylabel('Região')
g.set_xlabel('Usuários')
g.set_title('Usuários de internet no Brasil por Região (2013-2015) (% por região)')
plt.show()

# %% [markdown]
# **5 - Há diferença no número entre homens e mulheres que acessam a internet na região Sudeste?**
#
# Sim há uma diferença na média de cerca de 147 mulheres a mais que homens utilizando a internet no Sudeste.

# %%
newdf1 = dfs_idade_regiao[0].copy()
newdf2 = dfs_idade_regiao[1].copy()
newdf3 = dfs_idade_regiao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
diferença = newdf['Sudeste'][newdf['Sexo'] == 'Masculino'].mean() - newdf['Sudeste'][newdf['Sexo'] == 'Feminino'].mean()
diferença

# %% [markdown]
# **6 - O que mudou nesses 3 anos diante do acesso a internet**
#
# Oque podemos notar com base no gráfico é um aumento consideravel de novos usuários na internet, além de um grande aumento de usuários na população de 60 anos ou mais.

# %%
newdf1 = dfs_idade_regiao[0].copy()
newdf2 = dfs_idade_regiao[1].copy()
newdf3 = dfs_idade_regiao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Sudeste', y='Grupo de Idades',palette="Set2",hue = "Ano", orient='h')
g.set_xlabel('Usuários de internet no Brasil')
plt.show()

# %% [markdown]
# **7 - Diante do tratamento dos dados, há muitos ruidos detectados?**
#
# Não, os dados do dataframe não possuiam ruidos.

# %% [markdown]
# **8 - Níveis de instrução do usuários dividido por sexo de cada ano:**

# %%
plt.figure(figsize=(7,7))
g=sns.barplot(data=dfs_sexo_anosdeestudo[0], x='Brasil', y='Grupo de anos de estudos',palette="Set2",hue= "Sexo" ,orient='h')
g.set_ylabel('Grupo de anos de estudos')
g.set_xlabel('Usuários')
g.set_title('Usuários de internet no Brasil por Anos de Estudo (2013)')
plt.show()

# %%
plt.figure(figsize=(7,7))
g=sns.barplot(data=dfs_sexo_anosdeestudo[1], x='Brasil', y='Grupo de anos de estudos',palette="Set2",hue= "Sexo" ,orient='h')
g.set_ylabel('Grupo de anos de estudos')
g.set_xlabel('Usuários')
g.set_title('Usuários de internet no Brasil por Anos de Estudo (2014)')
plt.show()

# %%
plt.figure(figsize=(7,7))
g=sns.barplot(data=dfs_sexo_anosdeestudo[2], x='Brasil', y='Grupo de anos de estudos',palette="Set2",hue= "Sexo" ,orient='h')
g.set_ylabel('Grupo de anos de estudos')
g.set_xlabel('Usuários')
g.set_title('Usuários de internet no Brasil por Anos de Estudo (2015)')
plt.show()

# %% [markdown]
# **9 - Qual grupo de profissões mais utilizou a internet em cada ano?**
#
# Trabalhadores da produção de bens e serviços e de reparação e manutenção foram os que mais acessaram a internet nos três anos. É  interessante mostrar também que trabalhadores dos serviços passaram a ser segundo, passando os serviços administrativos e de ciências e artes.

# %%
newdf1 = dfs_profissao[0][dfs_profissao[0]['Utilizaram'] == "Sim"].copy()
newdf2 = dfs_profissao[1][dfs_profissao[1]['Utilizaram'] == "Sim"].copy()
newdf3 = dfs_profissao[2][dfs_profissao[2]['Utilizaram'] == "Sim"].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
newdf['Profissao'].replace('Ocupações maldefinidas', 'Ocupações mal definidas', inplace=True)
plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Brasil', y='Profissao',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Profissão')
g.set_xlabel('Usuários')
g.set_title('Usuários de internet no Brasil por Profissão (2013-2015)')
plt.show()

# %% [markdown]
# **10 - Qual foi a maior dificuldade no tratamento dos dados ?**
#
# A maior dificuldade no tratamento de dados se deu na fase inicial, por o dataframe possuir diversas tabelas e formatos diferentes, tivemos que fazer o tratamento manual de algumas colunas, realocação de alguns dados e ate mesmo criação de novas colunas.

# %% [markdown]
# **11 - Existe uma relação direta entre a região e pessoas acessando a internet ao longo dos anos?**
#
# Com os dados obtidos não pode-se afirmar que existe uma relação direta entre a região e pessoas acessando a internet. No entanto observando o gráfico mostrado abaixo, pode-se perceber que a região Sudeste é a que mais acessa a internet. Talvez pelo fato de ser a que tem mais pessoas e ser a mais rica.

# %%
from pandas._libs.lib import array_equivalent_object
newdf1 = dfs_idade_regiao[0].copy()
newdf2 = dfs_idade_regiao[1].copy()
newdf3 = dfs_idade_regiao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
groupIdades = newdf.groupby('Ano').sum().reset_index()

regioes = ['Centro-Oeste', 'Nordeste', 'Norte', 'Sudeste', 'Sul']
anos = ["2013", "2014", "2015"]
def filtro_regiao_ano(v_regiao, v_ano, group):
  arr_anos = []
  arr_usuarios = []
  group.set_index('Ano', inplace=True)
  for a in v_ano:
    for r in v_regiao:
      arr_usuarios.append(group.at[a,r])
      arr_anos.append(a)
  return arr_anos, arr_usuarios

v_anos, users = filtro_regiao_ano(regioes, anos, groupIdades)

df_regioes = pd.DataFrame()
df_regioes['Regioes'] = regioes + regioes + regioes
df_regioes['Usuarios'] = users
df_regioes['Anos'] = v_anos
df_regioes = df_regioes.sort_values(by='Usuarios')
plt.figure(figsize=(10,10))
g=sns.barplot(data=df_regioes, y='Regioes', x='Usuarios',palette="Set1",hue= "Anos" ,orient='h')
g.set_ylabel('Região')
g.set_xlabel('Usuários')
g.set_title('Usuários de internet no Brasil por Região (2013-2015)')
plt.show()

# %% [markdown]
# **12 - Qual foram os anos com a maior variação de acesso de internet?**
#
# A maior variação se obteve nos anos de 2013 a 2014, sendo essa cerca de 11.4%.

# %%
newdf1 = dfs_idade_regiao[0].copy()
newdf2 = dfs_idade_regiao[1].copy()
newdf3 = dfs_idade_regiao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
variacao2013a2014 = newdf['Brasil'][newdf['Ano'] == 2014].sum()/newdf['Brasil'][newdf['Ano'] == 2013].sum()
variacao2014a2015 = newdf['Brasil'][newdf['Ano'] == 2015].sum()/newdf['Brasil'][newdf['Ano'] == 2014].sum()
print(variacao2013a2014)
print(variacao2014a2015)

# %% [markdown]
# **13 - Existe relação entre a renda e o uso da internet?**
#
# Não necessariamente as pessoas com maior renda são as que mais acessam, mas conforme aumenta a renda, maior é a parcela de pessoas que usam e menor é a parcela de pessoas que não usam. A renda mais alta tem maior porcentagem de usuários , mas também possui uma amostra menor.

# %%
newdf1 = dfs_renda[0].copy()
newdf2 = dfs_renda[1].copy()
newdf3 = dfs_renda[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
newdf = newdf[newdf['Utilizaram']=='Sim']
plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Brasil', y='Renda',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Renda')
g.set_xlabel('Usuários')
g.set_title('Usuários de internet no Brasil por Renda (2013-2015)')
plt.show()

# %%
dfs_pc_rendas = []


for df in dfs_renda:
  rendas = df
  rendas['Pc'] = np.where(rendas['Utilizaram'] == "Sim", rendas['Brasil'], 0)
  nova_renda = rendas.groupby('Renda').sum().reset_index()
  nova_renda['Pc'] = nova_renda['Pc'] / nova_renda['Brasil']
  dfs_pc_rendas.append(nova_renda)

newdf1 = dfs_pc_rendas[0].copy()
newdf2 = dfs_pc_rendas[1].copy()
newdf3 = dfs_pc_rendas[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
plt.figure(figsize=(10,10))
newdf = newdf.sort_values(by='Pc')
g=sns.barplot(data=newdf, x='Pc', y='Renda',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Renda')
g.set_xlabel('Usuários')
g.set_title('Usuários de internet no Brasil por Renda (2013-2015) (% por categoria)')
plt.show()

# %% [markdown]
# **14 - A quantidade de pessoas de 11 a 14 anos que acessam internet sofreu mudanças ao longo dos anos?**
#
# Mudanças pouco significativas, como podemos ver no gráfico abaixo

# %%
newdf1 = dfs_idade_regiao[0].copy()
newdf2 = dfs_idade_regiao[1].copy()
newdf3 = dfs_idade_regiao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
plt.figure(figsize=(10,10))
mais10 = newdf[newdf['Grupo de Idades'] == "10 a 14 anos"]
g=sns.barplot(data=mais10, x='Brasil', y='Grupo de Idades',palette="Set1",hue= "Ano" ,orient='h')
g.set_xlabel('Usuários de internet no Brasil')
plt.show()

# %% [markdown]
# **15 - O total de pessoas de 60 anos ou mais que usam a internet sofreu mudanças ao longo dos anos?**
#
# Sim sofreu variações conforme mostra o grafico abaixo

# %%
newdf1 = dfs_idade_regiao[0].copy()
newdf2 = dfs_idade_regiao[1].copy()
newdf3 = dfs_idade_regiao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
plt.figure(figsize=(10,10))
mais60 = newdf[newdf['Grupo de Idades'] == "60 anos ou mais"]
g=sns.barplot(data=mais60, x='Brasil', y='Ano',palette="Set1",hue= "Grupo de Idades" ,orient='h')
g.set_xlabel('Usuários de internet no Brasil')
plt.show()

# %% [markdown]
# **16 - Qual faixa de idade sofreu maior variação no uso de internet ao longo desses anos?**
#
# O gráfico abaixa compara a quantidade de usuários de cada idade nos anos de 2013 e 2015. Ao analisá-lo pode-se notar que os grupos que mais sofreram aumento no número de acessos à internet foram os de 30 a 34 anos, 35 a 39 anos e 40 a 44 anos.
#
# Um dado interessante é que o grupo de 10 a 14 praticamente não sofreu alteração neste mesmo período.

# %%
newdf1 = dfs_idade_regiao[0].copy()
newdf2 = dfs_idade_regiao[1].copy()
newdf3 = dfs_idade_regiao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)


plt.figure(figsize=(10,10))

g=sns.barplot(data=newdf, x='Brasil', y='Grupo de Idades',palette="Set2",hue= "Ano" ,orient='h')
g.set_ylabel('Grupos de Idade')
g.set_xlabel('Quantidade de usuarios')
g.set_title('Usuários de internet no Brasil x Grupos de Idade')
plt.show()

# %% [markdown]
# **17 - Existe uma relação direta entre o grau de estudo do indivíduo e o acesso à internet?**
#
# Analisando o gráfico abaixo, pode-se dizer que em geral o acesso da internet tem sim uma relação com o grau de estudo dos indivíduos. Sendo que em todos os anos analisados os graus de estudo com maior acesso à internet foram Médio Completo, Fundamental incompleto e Superior Completo. Enquanto isso, pessoas sem nível de instrução tem muito menos acesso à internet em comparação com as demais.

# %%
newdf1 = df_nivel_instrucao[0].copy()
newdf2 = df_nivel_instrucao[1].copy()
newdf3 = df_nivel_instrucao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)

plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Brasil', y='Sexo e nivel de instrucao',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Grau de instrucao')
g.set_xlabel('Quantidade de usuarios')
g.set_title('Usuários de internet no Brasil x Nível de instrução (2013 - 2015')
plt.show()



print("\nAno de 2013")
i = df_nivel_instrucao[0][df_nivel_instrucao[0]['Brasil']==df_nivel_instrucao[0]['Brasil'].max()].index[0]
print(df_nivel_instrucao[0]['Sexo e nivel de instrucao'][i])
print("\nAno de 2014")
i = df_nivel_instrucao[1][df_nivel_instrucao[1]['Brasil']==df_nivel_instrucao[1]['Brasil'].max()].index[0]
print(df_nivel_instrucao[1]['Sexo e nivel de instrucao'][i])
print("\nAno de 2015")
i = df_nivel_instrucao[2][df_nivel_instrucao[2]['Brasil']==df_nivel_instrucao[2]['Brasil'].max()].index[0]
print(df_nivel_instrucao[2]['Sexo e nivel de instrucao'][i])

# %% [markdown]
# **18 - Para qual grupo de anos de estudos aumentou mais o número de usuários de internet?**

# %% [markdown]
# **19 - Dentre as profissões analisadas no estudo, qual teve maior quantidade de pessoas acessando a internet? E qual teve menos? Existe uma relação entre a profissão e o uso da internet?**
#
# A profissão que mais acessou a internet foi a de trabalhadores da produção de bens e serviços e de reparação e manutenção. Já a proffisão que menos acessou a internet foi a de Membros das forças armadas e auxiliares.
#
# Analisando o gráfico não é possível definir ao certo se existe uma relação direta entre a profissão e uso da internet já que em geral todas as profssiões possuem uma quantidade próxima de acessos. No entanto devemos destacar as profissões de Membros das forças armadas e auxiliares e Trabalhadores agrícolas, que possuem muito menos acesso à internet do que as outras profissões. Uma das causas pode ser a localização, que são de díficil acesso à internet.

# %%
newdf1 = dfs_profissao[0].copy()
newdf2 = dfs_profissao[1].copy()
newdf3 = dfs_profissao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
newdf = newdf[newdf['Utilizaram']=='Sim']
plt.figure(figsize=(10,10))
g=sns.barplot(data=newdf, x='Brasil', y='Profissao',palette="Set1",hue= "Ano" ,orient='h')
g.set_ylabel('Profissao')
g.set_xlabel('Usuários')
g.set_title('Usuários de internet no Brasil x Profissão (2013-2015)')
plt.show()

# %% [markdown]
# **20 - Qual sexo (masculino ou feminino) mais utilizou internet? Quantos % a mais que o outro?**
#
# Conforme podemos notar no calculo e no gráfico, pessoas do sexo feminino usam cerca de 9.1% a mais a internet do que os homens.

# %%
newdf1 = dfs_idade_regiao[0].copy()
newdf2 = dfs_idade_regiao[1].copy()
newdf3 = dfs_idade_regiao[2].copy()
newdf1.insert(8,"Ano","2013")
newdf2.insert(8,"Ano","2014")
newdf3.insert(8,"Ano","2015")
newdf = pd.concat([newdf1,newdf2,newdf3], sort=False)
plt.figure(figsize=(10,10))
mais60 = newdf[newdf['Grupo de Idades'] == "60 anos ou mais"]

plt.figure(figsize=(10,10))
g=sns.barplot(data=mais60, x='Brasil', y='Sexo',palette="Set1",hue= "Ano" ,orient='h')
g.set_xlabel('Usuários de internet no Brasil')
plt.show()

totalmulheres = newdf['Brasil'][newdf['Sexo'] == 'Feminino'].sum()
totalhomens = newdf['Brasil'][newdf['Sexo'] == 'Masculino'].sum()

porcentagem = (totalmulheres/totalhomens)*100 - 100
print(porcentagem)
